# %% [markdown]
# # Example of Abstract Retrieval
#
#
# In this example first was choose an article, the one was:
#
# Optimization of Water Distribution Network Design Using the Shuffled Frog Leaping Algorithm
#
# You can find the paper in the bellow link:
#
# https://ascelibrary.org/doi/10.1061/%28ASCE%290733-9496%282003%29129%3A3%28210%29
#
# The EID (Electronic Identifier) is: 2-s2.0-0038363680
#
# To understand how to get the EID of the article look in [how to get EID](getting_EID_example.ipynb) notebook.

# %% [markdown]
# To get informations about the chosen article the Elsevier API gives an [Abstract Retrieval API](https://dev.elsevier.com/documentation/AbstractRetrievalAPI.wadl).
#
# The bellow code was adapted from https://stackoverflow.com/a/33501538

# %%
import os
import requests

# %% [markdown]
# To work safely with my APIKey, dont show my APIKey publicaly, I saved my one in a environment variable.
# You can hardcode yours if you want, but remember do not publish your APIKey.

# %%
APIKey = os.environ['API_KEY']

# %%
url = 'https://api.elsevier.com/content/abstract/EID:{}?apiKey={}&view=REF'

EID = '2-s2.0-85052823139'

url = url.format(EID, APIKey)

headers = {'Accept':'application/json'}

response = requests.get(url, headers=headers)

# %% [markdown]
# There are a lot of possibilities with the respose object.

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '{"abstracts-retrieval-response": {"references": {\n    "reference": [\n        {\n            "scopus-eid": "2-s2.0-84978115007",\n            "citedby-count": "12",\n            "scopus-id": "84978115007",\n            "@_fa": "true",\n            "volisspag": {\n                "voliss": {\n                    "@volume": "52",\n                    "@issue": "7"\n                },\n                "pagerange": {\n                    "@first": "5179",\n                    "@last": "5194"\n                }\n            },\n            "sourcetitle": "Water Resources Research",\n            "@id": "1",\n            "title": "Actively heated high-resolution fiber-optic-distributed temperature sensing to quantify streambed flow dynamics in zones of strong groundwater upwelling",\n            "ce:doi": "10.1002/2015WR018219",\n            "author-list": {"author": [\n                {\n                    "ce:given-name": "Martin A.",\n                    "preferred-name": {\n                        "ce:given-name": "Martin A.",\n                        "ce:initials": "M.A.",\n                        "ce:surname": "Briggs",\n                        "ce:indexed-name": "Briggs M."\n                    },\n                    "@seq": "1",\n                    "ce:initials": "M.A.",\n                    "@_fa": "true",\n                    "affiliation": {\n                        "@id": "60011347",\n                        "@href": "https://api.elsevier.com/content/affiliation/affiliation_id/60011347"\n                    },\n                    "ce:surname": "Briggs",\n                    "@auid": "36162817300",\n                    "author-url": "https://api.elsevier.com/content/author/author_id/36162817300",\n                    "@force-array": "true",\n                    "ce:indexed-name": "Briggs M.A."\n                },\n                {\n                    "ce:given-name": "Sean F.",\n                    "preferred-name": {\n                        "ce:given-name": "Sean F.",\n                        "ce:initials": "S.F.",\n                        "ce:surname": "Buckley",\n                        "ce:indexed-name": "Buckley S."\n                    },\n                    "@seq": "2",\n                    "ce:initials": "S.F.",\n                    "@_fa": "true",\n                    "affiliation": {\n                        "@id": "60011347",\n                        "@href": "https://api.elsevier.com/content/affiliation/affiliation_id/60011347"\n                    },\n                    "ce:surname": "Buckley",\n                    "@auid": "55389924800",\n                    "author-url": "https://api.elsevier.com/content/author/author_id/55389924800",\n                    "@force-array": "true",\n                    "ce:indexed-name": "Buckley S.F."\n                },\n                {\n                    "ce:given-name": "John W.",\n                    "preferred-name": {\n                        "ce:given-name": "John W.",\n                        "ce:initials": "J.W.",\n                        "ce:surname": "Lane",\n                        "ce:indexed-name": "Lane J."\n                    },\n                    "@seq": "5",\n                    "ce:initials": "J.W.",\n                    "@_fa": "true",\n                    "affiliation": {\n                        "@id": "60011347",\n                        "@href": "https://api.elsevier.com/content/affiliation/affiliation_id/60011347"\n                    },\n                    "ce:surname": "Lane",\n                    "@auid": "7401532379",\n                    "ce:suffix": "Jr.",\n                    "author-url": "https://api.elsevier.com/content/author/author_id/7401532379",\n                    "@force-array": "true",\n                    "ce:indexed-name": "Lane J.W."\n                },\n                {\n                    "ce:given-name": "Amvrossios C.",\n                    "preferred-name": {\n                        "ce:given-name": "Amvr ...

# %%
json = response.json()
json
# Out:
# {'abstracts-retrieval-response': {'references': {'reference': [{'scopus-eid': '2-s2.0-84978115007',
#      'citedby-count': '12',
#      'scopus-id': '84978115007',
#      '@_fa': 'true',
#      'volisspag': {'voliss': {'@volume': '52', '@issue': '7'},
#       'pagerange': {'@first': '5179', '@last': '5194'}},
#      'sourcetitle': 'Water Resources Research',
#      '@id': '1',
#      'title': 'Actively heated high-resolution fiber-optic-distributed temperature sensing to quantify streambed flow dynamics in zones of strong groundwater upwelling',
#      'ce:doi': '10.1002/2015WR018219',
#      'author-list': {'author': [{'ce:given-name': 'Martin A.',
#         'preferred-name': {'ce:given-name': 'Martin A.',
#          'ce:initials': 'M.A.',
#          'ce:surname': 'Briggs',
#          'ce:indexed-name': 'Briggs M.'},
#         '@seq': '1',
#         'ce:initials': 'M.A.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60011347',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60011347'},
#         'ce:surname': 'Briggs',
#         '@auid': '36162817300',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/36162817300',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Briggs M.A.'},
#        {'ce:given-name': 'Sean F.',
#         'preferred-name': {'ce:given-name': 'Sean F.',
#          'ce:initials': 'S.F.',
#          'ce:surname': 'Buckley',
#          'ce:indexed-name': 'Buckley S.'},
#         '@seq': '2',
#         'ce:initials': 'S.F.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60011347',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60011347'},
#         'ce:surname': 'Buckley',
#         '@auid': '55389924800',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/55389924800',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Buckley S.F.'},
#        {'ce:given-name': 'John W.',
#         'preferred-name': {'ce:given-name': 'John W.',
#          'ce:initials': 'J.W.',
#          'ce:surname': 'Lane',
#          'ce:indexed-name': 'Lane J.'},
#         '@seq': '5',
#         'ce:initials': 'J.W.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60011347',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60011347'},
#         'ce:surname': 'Lane',
#         '@auid': '7401532379',
#         'ce:suffix': 'Jr.',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/7401532379',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Lane J.W.'},
#        {'ce:given-name': 'Amvrossios C.',
#         'preferred-name': {'ce:given-name': 'Amvrossios C.',
#          'ce:initials': 'A.C.',
#          'ce:surname': 'Bagtzoglou',
#          'ce:indexed-name': 'Bagtzoglou A.'},
#         '@seq': '3',
#         'ce:initials': 'A.C.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60022659',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60022659'},
#         'ce:surname': 'Bagtzoglou',
#         '@auid': '7003300087',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/7003300087',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Bagtzoglou A.C.'},
#        {'ce:given-name': 'Dale D.',
#         'preferred-name': {'ce:given-name': 'Dale D.',
#          'ce:initials': 'D.D.',
#          'ce:surname': 'Werkema',
#          'ce:indexed-name': 'Werkema D.'},
#         '@seq': '4',
#         'ce:initials': 'D.D.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60021439',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60021439'},
#         'ce:surname': 'Werkema',
#         '@auid': '6603081105',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/6603081105',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Werkema D.D.'}]},
#      'url': 'https://api.elsevier.com/content/abstract/scopus_id/84978115007'},
#     {'scopus-eid': '2-s2.0-0036695720',
#      'citedby-count': '6',
#      'scopus-id': '0036695720',
#      '@_fa': 'true',
#      'volisspag': {'voliss': {'@volume': '54', '@issue': '8'},
#       'pagerange': {'@first': '38', '@last': '41'}},
#      'sourcetitle': 'International Water Power and Dam Construction',
#      '@id': '2',
#      'title': 'Experiencing the Teton dam failure',
#      'author-list': {'author': [{'ce:given-name': 'Leo A.',
#         'preferred-name': {'ce:given-name': 'Leo A.',
#          'ce:initials': 'L.A.',
#          'ce:surname': 'Busch',
#          'ce:indexed-name': 'Busch L.'},
#         '@seq': '1',
#         'ce:initials': 'L.A.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '101384271',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/101384271'},
#         'ce:surname': 'Busch',
#         '@auid': '7005463547',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/7005463547',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Busch L.A.'}]},
#      'url': 'https://api.elsevier.com/content/abstract/scopus_id/0036695720'},
#     {'scopus-eid': '2-s2.0-0036609180',
#      'citedby-count': '14',
#      'scopus-id': '0036609180',
#      '@_fa': 'true',
#      'volisspag': {'voliss': {'@volume': '18', '@issue': '6'},
#       'pagerange': {'@first': '399', '@last': '409'}},
#      'sourcetitle': 'Communications in Numerical Methods in Engineering',
#      '@id': '3',
#      'title': 'Analysis of coupled seepage and temperature fields in concrete dam',
#      'ce:doi': '10.1002/cnm.498',
#      'author-list': {'author': [{'ce:given-name': 'Chai',
#         'preferred-name': {'ce:given-name': 'Chai',
#          'ce:initials': 'C.',
#          'ce:surname': 'Junrui',
#          'ce:indexed-name': 'Junrui C.'},
#         '@seq': '1',
#         'ce:initials': 'C.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60016521',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60016521'},
#         'ce:surname': 'Junrui',
#         '@auid': '23108840600',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/23108840600',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Junrui C.'},
#        {'ce:given-name': 'Chai',
#         'preferred-name': {'ce:given-name': 'Chai',
#          'ce:initials': 'C.',
#          'ce:surname': 'Junrui',
#          'ce:indexed-name': 'Junrui C.'},
#         '@seq': '1',
#         'ce:initials': 'C.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60016521',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60016521'},
#         'ce:surname': 'Junrui',
#         '@auid': '23108840600',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/23108840600',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Junrui C.'}]},
#      'url': 'https://api.elsevier.com/content/abstract/scopus_id/0036609180'},
#     {'scopus-eid': '2-s2.0-85007060782',
#      'citedby-count': '5',
#      'scopus-id': '85007060782',
#      '@_fa': 'true',
#      'volisspag': {'voliss': {'@volume': '16', '@issue': '1'},
#       'pagerange': {'@first': '50', '@last': '61'}},
#      'sourcetitle': 'Structural Health Monitoring',
#      '@id': '4',
#      'title': 'An experimental study: Fiber Bragg grating–hydrothermal cycling integration system for seepage monitoring of rockfill dams',
#      'ce:doi': '10.1177/1475921716661874',
#      'author-list': {'author': [{'ce:given-name': 'Jiang',
#         'preferred-name': {'ce:given-name': 'Jiang',
#          'ce:initials': 'J.',
#          'ce:surname': 'Chen',
#          'ce:indexed-name': 'Chen J.'},
#         '@seq': '1',
#         'ce:initials': 'J.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60016521',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60016521'},
#         'ce:surname': 'Chen',
#         '@auid': '9237998500',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/9237998500',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Chen J.'},
#        {'ce:given-name': 'Feng',
#         'preferred-name': {'ce:given-name': 'Feng',
#          'ce:initials': 'F.',
#          'ce:surname': 'Xiong',
#          'ce:indexed-name': 'Xiong F.'},
#         '@seq': '3',
#         'ce:initials': 'F.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60016521',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60016521'},
#         'ce:surname': 'Xiong',
#         '@auid': '55545861681',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/55545861681',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Xiong F.'},
#        {'ce:given-name': 'Qi',
#         'preferred-name': {'ce:given-name': 'Qi',
#          'ce:initials': 'Q.',
#          'ce:surname': 'Ge',
#          'ce:indexed-name': 'Ge Q.'},
#         '@seq': '4',
#         'ce:initials': 'Q.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60016521',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60016521'},
#         'ce:surname': 'Ge',
#         '@auid': '55236963200',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/55236963200',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Ge Q.'},
#        {'ce:given-name': 'Fei',
#         'preferred-name': {'ce:given-name': 'Fei',
#          'ce:initials': 'F.',
#          'ce:surname': 'Cheng',
#          'ce:indexed-name': 'Cheng F.'},
#         '@seq': '2',
#         'ce:initials': 'F.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60016521',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60016521'},
#         'ce:surname': 'Cheng',
#         '@auid': '54583295000',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/54583295000',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Cheng F.'},
#        {'ce:given-name': 'Shaojie',
#         'preferred-name': {'ce:given-name': 'Shaojie',
#          'ce:initials': 'S.',
#          'ce:surname': 'Zhang',
#          'ce:indexed-name': 'Zhang S.'},
#         '@seq': '5',
#         'ce:initials': 'S.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60020259',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60020259'},
#         'ce:surname': 'Zhang',
#         '@auid': '35249906100',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/35249906100',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Zhang S.'}]},
#      'url': 'https://api.elsevier.com/content/abstract/scopus_id/85007060782'},
#     {'scopus-eid': '2-s2.0-40449088905',
#      'citedby-count': '5',
#      'scopus-id': '40449088905',
#      '@_fa': 'true',
#      'volisspag': {'voliss': {'@issue': '175'}, 'pagerange': {'@first': '59'}},
#      'sourcetitle': 'Geotechnical Special Publication',
#      '@id': '5',
#      'title': 'Water leakage detection using optical fiber at the peribonka dam',
#      'ce:doi': '10.1061/40940(307)59',
#      'author-list': {'author': [{'ce:given-name': 'Alain',
#         'preferred-name': {'ce:given-name': 'Alain',
#          'ce:initials': 'A.',
#          'ce:surname': 'Coté',
#          'ce:indexed-name': 'Coté A.'},
#         '@seq': '1',
#         'ce:initials': 'A.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60022089',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60022089'},
#         'ce:surname': 'Coté',
#         '@auid': '57202663757',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/57202663757',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Cote A.'},
#        {'ce:given-name': 'Jean',
#         'preferred-name': {'ce:given-name': 'Jean',
#          'ce:initials': 'J.',
#          'ce:surname': 'Leduc',
#          'ce:indexed-name': 'Leduc J.'},
#         '@seq': '3',
#         'ce:initials': 'J.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60022089',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60022089'},
#         'ce:surname': 'Leduc',
#         '@auid': '7102688788',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/7102688788',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Leduc J.'},
#        {'ce:given-name': 'Pierre',
#         'preferred-name': {'ce:given-name': 'Pierre',
#          'ce:initials': 'P.',
#          'ce:surname': 'Noël',
#          'ce:indexed-name': 'Noël P.'},
#         '@seq': '4',
#         'ce:initials': 'P.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60022089',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60022089'},
#         'ce:surname': 'Noël',
#         '@auid': '57197997962',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/57197997962',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Noel P.'},
#        {'ce:given-name': 'Réal',
#         'preferred-name': {'ce:given-name': 'Réal',
#          'ce:initials': 'R.',
#          'ce:surname': 'Beauchemin',
#          'ce:indexed-name': 'Beauchemin R.'},
#         '@seq': '5',
#         'ce:initials': 'R.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60022089',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60022089'},
#         'ce:surname': 'Beauchemin',
#         '@auid': '25421159800',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/25421159800',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Beauchemin R.'},
#        {'ce:given-name': 'Mathieu',
#         'preferred-name': {'ce:given-name': 'Mathieu',
#          'ce:initials': 'M.',
#          'ce:surname': 'Soares',
#          'ce:indexed-name': 'Soares M.'},
#         '@seq': '6',
#         'ce:initials': 'M.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60022089',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60022089'},
#         'ce:surname': 'Soares',
#         '@auid': '55418326400',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/55418326400',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Soares M.'},
#        {'ce:given-name': 'Benoit',
#         'preferred-name': {'ce:given-name': 'Benoit',
#          'ce:initials': 'B.',
#          'ce:surname': 'Carrier',
#          'ce:indexed-name': 'Carrier B.'},
#         '@seq': '2',
#         'ce:initials': 'B.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60022089',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60022089'},
#         'ce:surname': 'Carrier',
#         '@auid': '56971967900',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/56971967900',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Carrier B.'},
#        {'ce:given-name': 'Christian',
#         'preferred-name': {'ce:given-name': 'Christian',
#          'ce:initials': 'C.',
#          'ce:surname': 'Garneau',
#          'ce:indexed-name': 'Garneau C.'},
#         '@seq': '7',
#         'ce:initials': 'C.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60022089',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60022089'},
#         'ce:surname': 'Garneau',
#         '@auid': '6506113401',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/6506113401',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Garneau C.'},
#        {'ce:given-name': 'Richard',
#         'preferred-name': {'ce:given-name': 'Richard',
#          'ce:initials': 'R.',
#          'ce:surname': 'Gervais',
#          'ce:indexed-name': 'Gervais R.'},
#         '@seq': '8',
#         'ce:initials': 'R.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60022089',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60022089'},
#         'ce:surname': 'Gervais',
#         '@auid': '23970825800',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/23970825800',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Gervais R.'}]},
#      'url': 'https://api.elsevier.com/content/abstract/scopus_id/40449088905'},
#     {'scopus-eid': '2-s2.0-84906725860',
#      'citedby-count': '11',
#      'scopus-id': '84906725860',
#      '@_fa': 'true',
#      'volisspag': {'voliss': {'@volume': '13', '@issue': '5'},
#       'pagerange': {'@first': '562', '@last': '576'}},
#      'sourcetitle': 'Structural Health Monitoring',
#      '@id': '6',
#      'title': 'Monitoring and early detection of internal erosion: Distributed sensing and processing',
#      'ce:doi': '10.1177/1475921714532994',
#      'author-list': {'author': [{'ce:given-name': 'Amir A.',
#         'preferred-name': {'ce:given-name': 'Amir A.',
#          'ce:initials': 'A.A.',
#          'ce:surname': 'Khan',
#          'ce:indexed-name': 'Khan A.'},
#         '@seq': '1',
#         'ce:initials': 'A.A.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60059937',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60059937'},
#         'ce:surname': 'Khan',
#         '@auid': '55473387400',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/55473387400',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Khan A.A.'},
#        {'ce:given-name': 'Valeriu',
#         'preferred-name': {'ce:given-name': 'Valeriu',
#          'ce:initials': 'V.',
#          'ce:surname': 'Vrabie',
#          'ce:indexed-name': 'Vrabie V.'},
#         '@seq': '2',
#         'ce:initials': 'V.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60019394',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60019394'},
#         'ce:surname': 'Vrabie',
#         '@auid': '24391426800',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/24391426800',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Vrabie V.'},
#        {'ce:given-name': 'Yves-Laurent',
#         'preferred-name': {'ce:given-name': 'Yves Laurent',
#          'ce:initials': 'Y.L.',
#          'ce:surname': 'Beck',
#          'ce:indexed-name': 'Beck Y.'},
#         '@seq': '3',
#         'ce:initials': 'Y.-L.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60029873',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60029873'},
#         'ce:surname': 'Beck',
#         '@auid': '55639056100',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/55639056100',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Beck Y.-L.'},
#        {'ce:given-name': 'Guy',
#         'preferred-name': {'ce:given-name': 'Guy',
#          'ce:initials': 'G.',
#          'ce:surname': "D'Urso",
#          'ce:indexed-name': "D'Urso G."},
#         '@seq': '5',
#         'ce:initials': 'G.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60029873',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60029873'},
#         'ce:surname': "D'Urso",
#         '@auid': '24390476900',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/24390476900',
#         '@force-array': 'true',
#         'ce:indexed-name': "D'Urso G."},
#        {'ce:given-name': 'Jerome I.',
#         'preferred-name': {'ce:given-name': 'Jerome I.',
#          'ce:initials': 'J.I.',
#          'ce:surname': 'Mars',
#          'ce:indexed-name': 'Mars J.'},
#         '@seq': '4',
#         'ce:initials': 'J.I.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60104170',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60104170'},
#         'ce:surname': 'Mars',
#         '@auid': '7004216193',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/7004216193',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Mars J.I.'}]},
#      'url': 'https://api.elsevier.com/content/abstract/scopus_id/84906725860'},
#     {'scopus-eid': '2-s2.0-84924222057',
#      'citedby-count': '97',
#      'scopus-id': '84924222057',
#      '@_fa': 'true',
#      'volisspag': {'voliss': {'@volume': '48', '@issue': '4'},
#       'pagerange': {'@first': '871', '@last': '906'}},
#      'sourcetitle': 'Materials and Structures/Materiaux et Constructions',
#      '@id': '7',
#      'title': 'Review: optical fiber sensors for civil engineering applications',
#      'ce:doi': '10.1617/s11527-013-0201-7',
#      'author-list': {'author': [{'ce:given-name': 'Christopher K. Y.',
#         'preferred-name': {'ce:given-name': 'Christopher K.Y.',
#          'ce:initials': 'C.K.Y.',
#          'ce:surname': 'Leung',
#          'ce:indexed-name': 'Leung C.'},
#         '@seq': '1',
#         'ce:initials': 'C.K.Y.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60008592',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60008592'},
#         'ce:surname': 'Leung',
#         '@auid': '7402612410',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/7402612410',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Leung C.K.Y.'},
#        {'ce:given-name': 'Kai Tai',
#         'preferred-name': {'ce:given-name': 'Kai Tai',
#          'ce:initials': 'K.T.',
#          'ce:surname': 'Wan',
#          'ce:indexed-name': 'Wan K.'},
#         '@seq': '2',
#         'ce:initials': 'K.T.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '111145152',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/111145152'},
#         'ce:surname': 'Wan',
#         '@auid': '12765319800',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/12765319800',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Wan K.T.'},
#        {'ce:given-name': 'Daniele',
#         'preferred-name': {'ce:given-name': 'Daniele',
#          'ce:initials': 'D.',
#          'ce:surname': 'Inaudi',
#          'ce:indexed-name': 'Inaudi D.'},
#         '@seq': '3',
#         'ce:initials': 'D.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '113212510',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/113212510'},
#         'ce:surname': 'Inaudi',
#         '@auid': '7004603826',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/7004603826',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Inaudi D.'},
#        {'ce:given-name': 'Xiaoyi',
#         'preferred-name': {'ce:given-name': 'Xiaoyi',
#          'ce:initials': 'X.',
#          'ce:surname': 'Bao',
#          'ce:indexed-name': 'Bao X.'},
#         '@seq': '4',
#         'ce:initials': 'X.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '106663407',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/106663407'},
#         'ce:surname': 'Bao',
#         '@auid': '7202850534',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/7202850534',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Bao X.'},
#        {'ce:given-name': 'Wolfgang',
#         'preferred-name': {'ce:given-name': 'Wolfgang',
#          'ce:initials': 'W.',
#          'ce:surname': 'Habel',
#          'ce:indexed-name': 'Habel W.'},
#         '@seq': '5',
#         'ce:initials': 'W.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60072294',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60072294'},
#         'ce:surname': 'Habel',
#         '@auid': '55886721200',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/55886721200',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Habel W.'},
#        {'ce:given-name': 'Zhi',
#         'preferred-name': {'ce:given-name': 'Zhi',
#          'ce:initials': 'Z.',
#          'ce:surname': 'Zhou',
#          'ce:indexed-name': 'Zhou Z.'},
#         '@seq': '6',
#         'ce:initials': 'Z.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60019616',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60019616'},
#         'ce:surname': 'Zhou',
#         '@auid': '7406098352',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/7406098352',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Zhou Z.'},
#        {'ce:given-name': 'Jinping',
#         'preferred-name': {'ce:given-name': 'Jinping',
#          'ce:initials': 'J.',
#          'ce:surname': 'Ou',
#          'ce:indexed-name': 'Ou J.'},
#         '@seq': '7',
#         'ce:initials': 'J.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60004538',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60004538'},
#         'ce:surname': 'Ou',
#         '@auid': '7202845830',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/7202845830',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Ou J.'},
#        {'ce:given-name': 'Masoud',
#         'preferred-name': {'ce:given-name': 'Masoud',
#          'ce:initials': 'M.',
#          'ce:surname': 'Ghandehari',
#          'ce:indexed-name': 'Ghandehari M.'},
#         '@seq': '8',
#         'ce:initials': 'M.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60108318',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60108318'},
#         'ce:surname': 'Ghandehari',
#         '@auid': '7003584135',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/7003584135',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Ghandehari M.'},
#        {'ce:given-name': 'Hwai Chung',
#         'preferred-name': {'ce:given-name': 'Hwai Chung',
#          'ce:initials': 'H.C.',
#          'ce:surname': 'Wu',
#          'ce:indexed-name': 'Wu H.'},
#         '@seq': '9',
#         'ce:initials': 'H.C.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60009408',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60009408'},
#         'ce:surname': 'Wu',
#         '@auid': '7405584876',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/7405584876',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Wu H.C.'},
#        {'ce:given-name': 'Michio',
#         'preferred-name': {'ce:given-name': 'Michio',
#          'ce:initials': 'M.',
#          'ce:surname': 'Imai',
#          'ce:indexed-name': 'Imai M.'},
#         '@seq': '10',
#         'ce:initials': 'M.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60103562',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60103562'},
#         'ce:surname': 'Imai',
#         '@auid': '36436991400',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/36436991400',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Imai M.'}]},
#      'url': 'https://api.elsevier.com/content/abstract/scopus_id/84924222057'},
#     {'scopus-eid': '2-s2.0-84871386956',
#      'citedby-count': '3',
#      'scopus-id': '84871386956',
#      '@_fa': 'true',
#      'volisspag': {'voliss': {'@volume': '2012'}},
#      'sourcetitle': 'Advances in OptoElectronics',
#      '@id': '8',
#      'title': 'Multiplexed FBG monitoring system for forecasting coalmine water inrush disaster',
#      'article-number': '895723',
#      'ce:doi': '10.1155/2012/895723',
#      'author-list': {'author': [{'preferred-name': {'ce:given-name': 'B.',
#          'ce:initials': 'B.',
#          'ce:surname': 'Liu',
#          'ce:indexed-name': 'Liu B.'},
#         '@seq': '1',
#         'ce:initials': 'B.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60031031',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60031031'},
#         'ce:surname': 'Liu',
#         '@auid': '57192375308',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/57192375308',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Liu B.'},
#        {'preferred-name': {'ce:given-name': 'S. C.',
#          'ce:initials': 'S.C.',
#          'ce:surname': 'Li',
#          'ce:indexed-name': 'Li S.'},
#         '@seq': '2',
#         'ce:initials': 'S.C.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60031031',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60031031'},
#         'ce:surname': 'Li',
#         '@auid': '24450726200',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/24450726200',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Li S.C.'},
#        {'preferred-name': {'ce:given-name': 'L. C.',
#          'ce:initials': 'L.C.',
#          'ce:surname': 'Nie',
#          'ce:indexed-name': 'Nie L.'},
#         '@seq': '5',
#         'ce:initials': 'L.C.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60031031',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60031031'},
#         'ce:surname': 'Nie',
#         '@auid': '36657456700',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/36657456700',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Nie L.C.'},
#        {'preferred-name': {'ce:given-name': 'J.',
#          'ce:initials': 'J.',
#          'ce:surname': 'Wang',
#          'ce:indexed-name': 'Wang J.'},
#         '@seq': '3',
#         'ce:initials': 'J.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60031031',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60031031'},
#         'ce:surname': 'Wang',
#         '@auid': '7701312763',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/7701312763',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Wang J.'},
#        {'preferred-name': {'ce:given-name': 'Q. M.',
#          'ce:initials': 'Q.M.',
#          'ce:surname': 'Sui',
#          'ce:indexed-name': 'Sui Q.'},
#         '@seq': '4',
#         'ce:initials': 'Q.M.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60031031',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60031031'},
#         'ce:surname': 'Sui',
#         '@auid': '15840475500',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/15840475500',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Sui Q.M.'},
#        {'preferred-name': {'ce:given-name': 'Z. F.',
#          'ce:initials': 'Z.F.',
#          'ce:surname': 'Wang',
#          'ce:indexed-name': 'Wang Z.'},
#         '@seq': '6',
#         'ce:initials': 'Z.F.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60031031',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60031031'},
#         'ce:surname': 'Wang',
#         '@auid': '56106045500',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/56106045500',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Wang Z.F.'},
#        {'preferred-name': {'ce:given-name': 'J.',
#          'ce:initials': 'J.',
#          'ce:surname': 'Wang',
#          'ce:indexed-name': 'Wang J.'},
#         '@seq': '3',
#         'ce:initials': 'J.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60033100',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#         'ce:surname': 'Wang',
#         '@auid': '7701312763',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/7701312763',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Wang J.'}]},
#      'url': 'https://api.elsevier.com/content/abstract/scopus_id/84871386956'},
#     {'scopus-eid': '2-s2.0-84868014007',
#      'citedby-count': '30',
#      'scopus-id': '84868014007',
#      '@_fa': 'true',
#      'volisspag': {'voliss': {'@volume': '21', '@issue': '11'}},
#      'sourcetitle': 'Smart Materials and Structures',
#      '@id': '9',
#      'title': 'Application of a distributed optical fiber sensing technique in monitoring the stress of precast piles',
#      'article-number': '115011',
#      'ce:doi': '10.1088/0964-1726/21/11/115011',
#      'author-list': {'author': [{'preferred-name': {'ce:given-name': 'Y.',
#          'ce:initials': 'Y.',
#          'ce:surname': 'Lu',
#          'ce:indexed-name': 'Lu Y.'},
#         '@seq': '1',
#         'ce:initials': 'Y.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60033100',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#         'ce:surname': 'Lu',
#         '@auid': '23393022800',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/23393022800',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Lu Y.'},
#        {'preferred-name': {'ce:given-name': 'B.',
#          'ce:initials': 'B.',
#          'ce:surname': 'Shi',
#          'ce:indexed-name': 'Shi B.'},
#         '@seq': '2',
#         'ce:initials': 'B.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60033100',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#         'ce:surname': 'Shi',
#         '@auid': '7402545779',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/7402545779',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Shi B.'},
#        {'preferred-name': {'ce:given-name': 'G. Q.',
#          'ce:initials': 'G.Q.',
#          'ce:surname': 'Wei',
#          'ce:indexed-name': 'Wei G.'},
#         '@seq': '3',
#         'ce:initials': 'G.Q.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60033100',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#         'ce:surname': 'Wei',
#         '@auid': '24386049800',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/24386049800',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Wei G.Q.'},
#        {'preferred-name': {'ce:given-name': 'D.',
#          'ce:initials': 'D.',
#          'ce:surname': 'Zhang',
#          'ce:indexed-name': 'Zhang D.'},
#         '@seq': '5',
#         'ce:initials': 'D.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60033100',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#         'ce:surname': 'Zhang',
#         '@auid': '55717553100',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/55717553100',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Zhang D.'},
#        {'preferred-name': {'ce:given-name': 'S. E.',
#          'ce:initials': 'S.E.',
#          'ce:surname': 'Chen',
#          'ce:indexed-name': 'Chen S.'},
#         '@seq': '4',
#         'ce:initials': 'S.E.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60006951',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60006951'},
#         'ce:surname': 'Chen',
#         '@auid': '14033942200',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/14033942200',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Chen S.E.'}]},
#      'url': 'https://api.elsevier.com/content/abstract/scopus_id/84868014007'},
#     {'scopus-eid': '2-s2.0-84855925873',
#      'citedby-count': '58',
#      'scopus-id': '84855925873',
#      '@_fa': 'true',
#      'volisspag': {'voliss': {'@volume': '137', '@issue': '12'},
#       'pagerange': {'@first': '1236', '@last': '1243'}},
#      'sourcetitle': 'Journal of Geotechnical and Geoenvironmental Engineering',
#      '@id': '10',
#      'title': 'Performance monitoring of a secant-piled wall using distributed fiber optic strain sensing',
#      'ce:doi': '10.1061/(ASCE)GT.1943-5606.0000543',
#      'author-list': {'author': [{'ce:given-name': 'Hisham',
#         'preferred-name': {'ce:given-name': 'Hisham',
#          'ce:initials': 'H.',
#          'ce:surname': 'Mohamad',
#          'ce:indexed-name': 'Mohamad H.'},
#         '@seq': '1',
#         'ce:initials': 'H.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60021005',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60021005'},
#         'ce:surname': 'Mohamad',
#         '@auid': '23971181600',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/23971181600',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Mohamad H.'},
#        {'ce:given-name': 'Kenichi',
#         'preferred-name': {'ce:given-name': 'Kenichi',
#          'ce:initials': 'K.',
#          'ce:surname': 'Soga',
#          'ce:indexed-name': 'Soga K.'},
#         '@seq': '2',
#         'ce:initials': 'K.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60031101',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60031101'},
#         'ce:surname': 'Soga',
#         '@auid': '7102442890',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/7102442890',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Soga K.'},
#        {'ce:given-name': 'Adam',
#         'preferred-name': {'ce:given-name': 'Adam',
#          'ce:initials': 'A.',
#          'ce:surname': 'Pellew',
#          'ce:indexed-name': 'Pellew A.'},
#         '@seq': '3',
#         'ce:initials': 'A.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '112601714',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/112601714'},
#         'ce:surname': 'Pellew',
#         '@auid': '54897924000',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/54897924000',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Pellew A.'},
#        {'ce:given-name': 'Peter J.',
#         'preferred-name': {'ce:given-name': 'Peter J.',
#          'ce:initials': 'P.J.',
#          'ce:surname': 'Bennett',
#          'ce:indexed-name': 'Bennett P.'},
#         '@seq': '4',
#         'ce:initials': 'P.J.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60031101',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60031101'},
#         'ce:surname': 'Bennett',
#         '@auid': '24309693700',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/24309693700',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Bennett P.J.'}]},
#      'url': 'https://api.elsevier.com/content/abstract/scopus_id/84855925873'},
#     {'scopus-eid': '2-s2.0-36749072655',
#      'citedby-count': '27',
#      'scopus-id': '36749072655',
#      '@_fa': 'true',
#      'volisspag': {'voliss': {'@volume': '18', '@issue': '10'},
#       'pagerange': {'@first': '3202', '@last': '3210'}},
#      'sourcetitle': 'Measurement Science and Technology',
#      '@id': '11',
#      'title': 'Application of a distributed fibre optic strain sensing system to monitoring changes in the state of an underground mine',
#      'ce:doi': '10.1088/0957-0233/18/10/S23',
#      'author-list': {'author': [{'ce:given-name': 'Hiroshi',
#         'preferred-name': {'ce:given-name': 'Hiroshi',
#          'ce:initials': 'H.',
#          'ce:surname': 'Naruse',
#          'ce:indexed-name': 'Naruse H.'},
#         '@seq': '1',
#         'ce:initials': 'H.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60018873',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60018873'},
#         'ce:surname': 'Naruse',
#         '@auid': '7102785206',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/7102785206',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Naruse H.'},
#        {'ce:given-name': 'Hideki',
#         'preferred-name': {'ce:given-name': 'Hideki',
#          'ce:initials': 'H.',
#          'ce:surname': 'Uehara',
#          'ce:indexed-name': 'Uehara H.'},
#         '@seq': '2',
#         'ce:initials': 'H.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60025555',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60025555'},
#         'ce:surname': 'Uehara',
#         '@auid': '7202112265',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/7202112265',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Uehara H.'},
#        {'ce:given-name': 'Taishi',
#         'preferred-name': {'ce:given-name': 'Taishi',
#          'ce:initials': 'T.',
#          'ce:surname': 'Deguchi',
#          'ce:indexed-name': 'Deguchi T.'},
#         '@seq': '3',
#         'ce:initials': 'T.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60025555',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60025555'},
#         'ce:surname': 'Deguchi',
#         '@auid': '7201725538',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/7201725538',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Deguchi T.'},
#        {'ce:given-name': 'Kazuhiko',
#         'preferred-name': {'ce:given-name': 'Kazuhiko',
#          'ce:initials': 'K.',
#          'ce:surname': 'Fujihashi',
#          'ce:indexed-name': 'Fujihashi K.'},
#         '@seq': '4',
#         'ce:initials': 'K.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60025555',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60025555'},
#         'ce:surname': 'Fujihashi',
#         '@auid': '22034495400',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/22034495400',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Fujihashi K.'},
#        {'ce:given-name': 'Masatoshi',
#         'preferred-name': {'ce:given-name': 'Masatoshi',
#          'ce:initials': 'M.',
#          'ce:surname': 'Onishi',
#          'ce:indexed-name': 'Onishi M.'},
#         '@seq': '5',
#         'ce:initials': 'M.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60093328',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60093328'},
#         'ce:surname': 'Onishi',
#         '@auid': '23029117300',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/23029117300',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Onishi M.'},
#        {'ce:given-name': 'Raul',
#         'preferred-name': {'ce:given-name': 'Raul',
#          'ce:initials': 'R.',
#          'ce:surname': 'Espinoza',
#          'ce:indexed-name': 'Espinoza R.'},
#         '@seq': '6',
#         'ce:initials': 'R.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60004849',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60004849'},
#         'ce:surname': 'Espinoza',
#         '@auid': '36886510600',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/36886510600',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Espinoza R.'},
#        {'ce:given-name': 'Cesar',
#         'preferred-name': {'ce:given-name': 'Cesar',
#          'ce:initials': 'C.',
#          'ce:surname': 'Guzman',
#          'ce:indexed-name': 'Guzman C.'},
#         '@seq': '7',
#         'ce:initials': 'C.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60004849',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60004849'},
#         'ce:surname': 'Guzman',
#         '@auid': '57198172982',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/57198172982',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Guzman C.'},
#        {'ce:given-name': 'Cesar',
#         'preferred-name': {'ce:given-name': 'Cesar',
#          'ce:initials': 'C.',
#          'ce:surname': 'Pardo',
#          'ce:indexed-name': 'Pardo C.'},
#         '@seq': '8',
#         'ce:initials': 'C.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60004849',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60004849'},
#         'ce:surname': 'Pardo',
#         '@auid': '23029104500',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/23029104500',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Pardo C.'},
#        {'ce:given-name': 'Cesar',
#         'preferred-name': {'ce:given-name': 'Cesar',
#          'ce:initials': 'C.',
#          'ce:surname': 'Ortega',
#          'ce:indexed-name': 'Ortega C.'},
#         '@seq': '9',
#         'ce:initials': 'C.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60004849',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60004849'},
#         'ce:surname': 'Ortega',
#         '@auid': '23029088400',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/23029088400',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Ortega C.'},
#        {'ce:given-name': 'Manuel',
#         'preferred-name': {'ce:given-name': 'Manuel',
#          'ce:initials': 'M.',
#          'ce:surname': 'Pinto',
#          'ce:indexed-name': 'Pinto M.'},
#         '@seq': '10',
#         'ce:initials': 'M.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60004849',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60004849'},
#         'ce:surname': 'Pinto',
#         '@auid': '57198389447',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/57198389447',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Pinto M.'}]},
#      'url': 'https://api.elsevier.com/content/abstract/scopus_id/36749072655'},
#     {'scopus-eid': '2-s2.0-77951566656',
#      'citedby-count': '233',
#      'scopus-id': '77951566656',
#      '@_fa': 'true',
#      'volisspag': {'voliss': {'@volume': '9', '@issue': '3'},
#       'pagerange': {'@first': '219', '@last': '231'}},
#      'sourcetitle': 'Structural Health Monitoring',
#      '@id': '12',
#      'title': 'Structural health monitoring in mainland china: Review and future trends',
#      'ce:doi': '10.1177/1475921710365269',
#      'author-list': {'author': [{'ce:given-name': 'Jinping',
#         'preferred-name': {'ce:given-name': 'Jinping',
#          'ce:initials': 'J.',
#          'ce:surname': 'Ou',
#          'ce:indexed-name': 'Ou J.'},
#         '@seq': '1',
#         'ce:initials': 'J.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60004538',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60004538'},
#         'ce:surname': 'Ou',
#         '@auid': '7202845830',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/7202845830',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Ou J.'},
#        {'ce:given-name': 'Jinping',
#         'preferred-name': {'ce:given-name': 'Jinping',
#          'ce:initials': 'J.',
#          'ce:surname': 'Ou',
#          'ce:indexed-name': 'Ou J.'},
#         '@seq': '1',
#         'ce:initials': 'J.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60019616',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60019616'},
#         'ce:surname': 'Ou',
#         '@auid': '7202845830',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/7202845830',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Ou J.'},
#        {'ce:given-name': 'Hui',
#         'preferred-name': {'ce:given-name': 'Hui',
#          'ce:initials': 'H.',
#          'ce:surname': 'Li',
#          'ce:indexed-name': 'Li H.'},
#         '@seq': '2',
#         'ce:initials': 'H.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60019616',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60019616'},
#         'ce:surname': 'Li',
#         '@auid': '57202721115',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/57202721115',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Li H.'}]},
#      'url': 'https://api.elsevier.com/content/abstract/scopus_id/77951566656'},
#     {'scopus-eid': '2-s2.0-84907818061',
#      'citedby-count': '27',
#      'scopus-id': '84907818061',
#      '@_fa': 'true',
#      'volisspag': {'voliss': {'@volume': '58'},
#       'pagerange': {'@first': '207', '@last': '214'}},
#      'sourcetitle': 'Measurement: Journal of the International Measurement Confederation',
#      '@id': '13',
#      'title': 'A review of previous studies on the applications of optical fiber sensors in geotechnical health monitoring',
#      'ce:doi': '10.1016/j.measurement.2014.08.013',
#      'author-list': {'author': [{'ce:given-name': 'Hua-Fu',
#         'preferred-name': {'ce:given-name': 'Hua Fu',
#          'ce:initials': 'H.F.',
#          'ce:surname': 'Pei',
#          'ce:indexed-name': 'Pei H.'},
#         '@seq': '1',
#         'ce:initials': 'H.-F.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60019616',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60019616'},
#         'ce:surname': 'Pei',
#         '@auid': '36444934100',
# ...
#         'ce:surname': 'Chen',
#         '@auid': '57188710464',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/57188710464',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Chen J.'},
#        {'ce:given-name': 'Jin',
#         'preferred-name': {'ce:given-name': 'Jin',
#          'ce:initials': 'J.',
#          'ce:surname': 'Wang',
#          'ce:indexed-name': 'Wang J.'},
#         '@seq': '3',
#         'ce:initials': 'J.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60021783',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60021783'},
#         'ce:surname': 'Wang',
#         '@auid': '57188712439',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/57188712439',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Wang J.'},
#        {'ce:given-name': 'Jianping',
#         'preferred-name': {'ce:given-name': 'Jianping',
#          'ce:initials': 'J.',
#          'ce:surname': 'Chen',
#          'ce:indexed-name': 'Chen J.'},
#         '@seq': '4',
#         'ce:initials': 'J.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60021783',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60021783'},
#         'ce:surname': 'Chen',
#         '@auid': '57188710475',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/57188710475',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Chen J.'}]},
#      'url': 'https://api.elsevier.com/content/abstract/scopus_id/84962382655'},
#     {'scopus-eid': '2-s2.0-84878031896',
#      'citedby-count': '10',
#      'scopus-id': '84878031896',
#      '@_fa': 'true',
#      'volisspag': {'voliss': {'@volume': '36', '@issue': '3'}},
#      'sourcetitle': 'Geotechnical Testing Journal',
#      '@id': '19',
#      'title': 'Experimental study of the applications of fiber optic distributed temperature sensors in detecting seepage in soils',
#      'ce:doi': '10.1520/GTJ20120096',
#      'author-list': {'author': [{'ce:given-name': 'Henglin',
#         'preferred-name': {'ce:given-name': 'Henglin',
#          'ce:initials': 'H.',
#          'ce:surname': 'Xiao',
#          'ce:indexed-name': 'Xiao H.'},
#         '@seq': '1',
#         'ce:initials': 'H.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60108756',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60108756'},
#         'ce:surname': 'Xiao',
#         '@auid': '7401565435',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/7401565435',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Xiao H.'},
#        {'ce:given-name': 'Jie',
#         'preferred-name': {'ce:given-name': 'Jie',
#          'ce:initials': 'J.',
#          'ce:surname': 'Huang',
#          'ce:indexed-name': 'Huang J.'},
#         '@seq': '2',
#         'ce:initials': 'J.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60003212',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60003212'},
#         'ce:surname': 'Huang',
#         '@auid': '55742397700',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/55742397700',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Huang J.'}]},
#      'url': 'https://api.elsevier.com/content/abstract/scopus_id/84878031896'},
#     {'scopus-eid': '2-s2.0-85027924941',
#      'citedby-count': '10',
#      'scopus-id': '85027924941',
#      '@_fa': 'true',
#      'volisspag': {'voliss': {'@volume': '186'},
#       'pagerange': {'@first': '100', '@last': '104'}},
#      'sourcetitle': 'Engineering Geology',
#      '@id': '20',
#      'title': 'A quantitative monitoring technology for seepage in slopes using DTS',
#      'ce:doi': '10.1016/j.enggeo.2015.01.001',
#      'author-list': {'author': [{'ce:given-name': 'Jun-Fan',
#         'preferred-name': {'ce:given-name': 'Jun Fan',
#          'ce:initials': 'J.F.',
#          'ce:surname': 'Yan',
#          'ce:indexed-name': 'Yan J.'},
#         '@seq': '1',
#         'ce:initials': 'J.-F.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60033100',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#         'ce:surname': 'Yan',
#         '@auid': '55668100800',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/55668100800',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Yan J.-F.'},
#        {'ce:given-name': 'Bin',
#         'preferred-name': {'ce:given-name': 'Bin',
#          'ce:initials': 'B.',
#          'ce:surname': 'Shi',
#          'ce:indexed-name': 'Shi B.'},
#         '@seq': '2',
#         'ce:initials': 'B.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60033100',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#         'ce:surname': 'Shi',
#         '@auid': '7402545779',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/7402545779',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Shi B.'},
#        {'ce:given-name': 'Hong-Hu',
#         'preferred-name': {'ce:given-name': 'Hong Hu',
#          'ce:initials': 'H.H.',
#          'ce:surname': 'Zhu',
#          'ce:indexed-name': 'Zhu H.'},
#         '@seq': '3',
#         'ce:initials': 'H.-H.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60033100',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#         'ce:surname': 'Zhu',
#         '@auid': '12140186000',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/12140186000',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Zhu H.-H.'},
#        {'ce:given-name': 'Bao-Jun',
#         'preferred-name': {'ce:given-name': 'Bao Jun',
#          'ce:initials': 'B.J.',
#          'ce:surname': 'Wang',
#          'ce:indexed-name': 'Wang B.'},
#         '@seq': '4',
#         'ce:initials': 'B.-J.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60033100',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#         'ce:surname': 'Wang',
#         '@auid': '57188823130',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/57188823130',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Wang B.-J.'},
#        {'ce:given-name': 'Ding-Feng',
#         'preferred-name': {'ce:given-name': 'Ding Feng',
#          'ce:initials': 'D.F.',
#          'ce:surname': 'Cao',
#          'ce:indexed-name': 'Cao D.'},
#         '@seq': '6',
#         'ce:initials': 'D.-F.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60033100',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#         'ce:surname': 'Cao',
#         '@auid': '56184645000',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/56184645000',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Cao D.-F.'},
#        {'ce:given-name': 'Guang-Qing',
#         'preferred-name': {'ce:given-name': 'Guang Qing',
#          'ce:initials': 'G.Q.',
#          'ce:surname': 'Wei',
#          'ce:indexed-name': 'Wei G.'},
#         '@seq': '5',
#         'ce:initials': 'G.-Q.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '114724446',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/114724446'},
#         'ce:surname': 'Wei',
#         '@auid': '24386049800',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/24386049800',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Wei G.-Q.'}]},
#      'url': 'https://api.elsevier.com/content/abstract/scopus_id/85027924941'},
#     {'scopus-eid': '2-s2.0-84906237126',
#      'citedby-count': '35',
#      'scopus-id': '84906237126',
#      '@_fa': 'true',
#      'volisspag': {'voliss': {'@volume': '23', '@issue': '9'}},
#      'sourcetitle': 'Smart Materials and Structures',
#      '@id': '21',
#      'title': 'Fiber Bragg grating-based performance monitoring of a slope model subjected to seepage',
#      'article-number': '095027',
#      'ce:doi': '10.1088/0964-1726/23/9/095027',
#      'author-list': {'author': [{'ce:given-name': 'Hong-Hu',
#         'preferred-name': {'ce:given-name': 'Hong Hu',
#          'ce:initials': 'H.H.',
#          'ce:surname': 'Zhu',
#          'ce:indexed-name': 'Zhu H.'},
#         '@seq': '1',
#         'ce:initials': 'H.-H.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60033100',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#         'ce:surname': 'Zhu',
#         '@auid': '12140186000',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/12140186000',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Zhu H.-H.'},
#        {'ce:given-name': 'Bin',
#         'preferred-name': {'ce:given-name': 'Bin',
#          'ce:initials': 'B.',
#          'ce:surname': 'Shi',
#          'ce:indexed-name': 'Shi B.'},
#         '@seq': '2',
#         'ce:initials': 'B.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60033100',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#         'ce:surname': 'Shi',
#         '@auid': '7402545779',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/7402545779',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Shi B.'},
#        {'ce:given-name': 'Jun-Fan',
#         'preferred-name': {'ce:given-name': 'Jun Fan',
#          'ce:initials': 'J.F.',
#          'ce:surname': 'Yan',
#          'ce:indexed-name': 'Yan J.'},
#         '@seq': '3',
#         'ce:initials': 'J.-F.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60033100',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#         'ce:surname': 'Yan',
#         '@auid': '55668100800',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/55668100800',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Yan J.-F.'},
#        {'ce:given-name': 'Cheng-Cheng',
#         'preferred-name': {'ce:given-name': 'Cheng Cheng',
#          'ce:initials': 'C.C.',
#          'ce:surname': 'Zhang',
#          'ce:indexed-name': 'Zhang C.'},
#         '@seq': '5',
#         'ce:initials': 'C.-C.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60033100',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#         'ce:surname': 'Zhang',
#         '@auid': '55628533917',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/55628533917',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Zhang C.-C.'},
#        {'ce:given-name': 'Bao-Jun',
#         'preferred-name': {'ce:given-name': 'Bao Jun',
#          'ce:initials': 'B.J.',
#          'ce:surname': 'Wang',
#          'ce:indexed-name': 'Wang B.'},
#         '@seq': '6',
#         'ce:initials': 'B.-J.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60033100',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#         'ce:surname': 'Wang',
#         '@auid': '57188823130',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/57188823130',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Wang B.-J.'},
#        {'ce:given-name': 'Jie',
#         'preferred-name': {'ce:given-name': 'Jie',
#          'ce:initials': 'J.',
#          'ce:surname': 'Zhang',
#          'ce:indexed-name': 'Zhang J.'},
#         '@seq': '4',
#         'ce:initials': 'J.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60073652',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60073652'},
#         'ce:surname': 'Zhang',
#         '@auid': '55934252000',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/55934252000',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Zhang J.'}]},
#      'url': 'https://api.elsevier.com/content/abstract/scopus_id/84906237126'},
#     {'scopus-eid': '2-s2.0-79955364443',
#      'citedby-count': '7',
#      'scopus-id': '79955364443',
#      '@_fa': 'true',
#      'volisspag': {'voliss': {'@volume': '8'},
#       'pagerange': {'@first': '520', '@last': '526'}},
#      'sourcetitle': 'Procedia Engineering',
#      '@id': '22',
#      'title': 'Safety inspection strategy for earth embankment dams using fully distributed sensing',
#      'ce:doi': '10.1016/j.proeng.2011.03.094',
#      'author-list': {'author': [{'ce:given-name': 'Pingyu',
#         'preferred-name': {'ce:given-name': 'Pingyu',
#          'ce:initials': 'P.',
#          'ce:surname': 'Zhu',
#          'ce:indexed-name': 'Zhu P.'},
#         '@seq': '1',
#         'ce:initials': 'P.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60024617',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60024617'},
#         'ce:surname': 'Zhu',
#         '@auid': '7202169460',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/7202169460',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Zhu P.'},
#        {'preferred-name': {'ce:given-name': 'Y.',
#          'ce:initials': 'Y.',
#          'ce:surname': 'Zhou',
#          'ce:indexed-name': 'Zhou Y.'},
#         '@seq': '3',
#         'ce:initials': 'Y.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60024617',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60024617'},
#         'ce:surname': 'Zhou',
#         '@auid': '35209382100',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/35209382100',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Zhou Y.'},
#        {'preferred-name': {'ce:given-name': 'G. L.',
#          'ce:initials': 'G.L.',
#          'ce:surname': 'Jiang',
#          'ce:indexed-name': 'Jiang G.'},
#         '@seq': '4',
#         'ce:initials': 'G.L.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60024617',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60024617'},
#         'ce:surname': 'Jiang',
#         '@auid': '35204964900',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/35204964900',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Jiang G.L.'},
#        {'preferred-name': {'ce:given-name': 'Y. B.',
#          'ce:initials': 'Y.B.',
#          'ce:surname': 'Leng',
#          'ce:indexed-name': 'Leng Y.'},
#         '@seq': '2',
#         'ce:initials': 'Y.B.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60081483',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60081483'},
#         'ce:surname': 'Leng',
#         '@auid': '16205061800',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/16205061800',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Leng Y.B.'},
#        {'preferred-name': {'ce:given-name': 'Y.',
#          'ce:initials': 'Y.',
#          'ce:surname': 'Zhou',
#          'ce:indexed-name': 'Zhou Y.'},
#         '@seq': '3',
#         'ce:initials': 'Y.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60081483',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60081483'},
#         'ce:surname': 'Zhou',
#         '@auid': '35209382100',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/35209382100',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Zhou Y.'},
#        {'preferred-name': {'ce:given-name': 'G. L.',
#          'ce:initials': 'G.L.',
#          'ce:surname': 'Jiang',
#          'ce:indexed-name': 'Jiang G.'},
#         '@seq': '4',
#         'ce:initials': 'G.L.',
#         '@_fa': 'true',
#         'affiliation': {'@id': '60081483',
#          '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60081483'},
#         'ce:surname': 'Jiang',
#         '@auid': '35204964900',
#         'author-url': 'https://api.elsevier.com/content/author/author_id/35204964900',
#         '@force-array': 'true',
#         'ce:indexed-name': 'Jiang G.L.'}]},
#      'url': 'https://api.elsevier.com/content/abstract/scopus_id/79955364443'}],
#    '@total-references': '22'}}}

# %% [markdown]
# Note that the json variable is a dict.

# %%
type(json)
# Out:
# dict

# %%
json.keys()
# Out:
# dict_keys(['abstracts-retrieval-response'])

# %%
json['abstracts-retrieval-response'].keys()
# Out:
# dict_keys(['references'])

# %%
json['abstracts-retrieval-response']['references'].keys()
# Out:
# dict_keys(['reference', '@total-references'])

# %%
json['abstracts-retrieval-response']['references']['@total-references']
# Out:
# '22'

# %% [markdown]
# Clicking in the title of the article is possible to check that the article has 37 references and only 22 were returned by the API. See the
# [link](https://www-scopus.ez18.periodicos.capes.gov.br/record/display.uri?eid=2-s2.0-0038363680&origin=resultslist&sort=plf-f&src=s&st1=%22Optimization+of+Water+Distribution+Network+Design+Using+the+Shuffled+Frog+Leaping+Algorithm%22&st2=&sid=0ac77cd69a862976ec6119128b551c0c&sot=b&sdt=b&sl=108&s=TITLE-ABS-KEY%28%22Optimization+of+Water+Distribution+Network+Design+Using+the+Shuffled+Frog+Leaping+Algorithm%22%29&relpos=0&citeCnt=831&searchTerm=) to the artice in the Elsevier site.

# %%
len(json['abstracts-retrieval-response']['references']['reference'])
# Out:
# 22

# %%
json['abstracts-retrieval-response']['references']['reference']
# Out:
# [{'scopus-eid': '2-s2.0-84978115007',
#   'citedby-count': '12',
#   'scopus-id': '84978115007',
#   '@_fa': 'true',
#   'volisspag': {'voliss': {'@volume': '52', '@issue': '7'},
#    'pagerange': {'@first': '5179', '@last': '5194'}},
#   'sourcetitle': 'Water Resources Research',
#   '@id': '1',
#   'title': 'Actively heated high-resolution fiber-optic-distributed temperature sensing to quantify streambed flow dynamics in zones of strong groundwater upwelling',
#   'ce:doi': '10.1002/2015WR018219',
#   'author-list': {'author': [{'ce:given-name': 'Martin A.',
#      'preferred-name': {'ce:given-name': 'Martin A.',
#       'ce:initials': 'M.A.',
#       'ce:surname': 'Briggs',
#       'ce:indexed-name': 'Briggs M.'},
#      '@seq': '1',
#      'ce:initials': 'M.A.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60011347',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60011347'},
#      'ce:surname': 'Briggs',
#      '@auid': '36162817300',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/36162817300',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Briggs M.A.'},
#     {'ce:given-name': 'Sean F.',
#      'preferred-name': {'ce:given-name': 'Sean F.',
#       'ce:initials': 'S.F.',
#       'ce:surname': 'Buckley',
#       'ce:indexed-name': 'Buckley S.'},
#      '@seq': '2',
#      'ce:initials': 'S.F.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60011347',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60011347'},
#      'ce:surname': 'Buckley',
#      '@auid': '55389924800',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/55389924800',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Buckley S.F.'},
#     {'ce:given-name': 'John W.',
#      'preferred-name': {'ce:given-name': 'John W.',
#       'ce:initials': 'J.W.',
#       'ce:surname': 'Lane',
#       'ce:indexed-name': 'Lane J.'},
#      '@seq': '5',
#      'ce:initials': 'J.W.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60011347',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60011347'},
#      'ce:surname': 'Lane',
#      '@auid': '7401532379',
#      'ce:suffix': 'Jr.',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7401532379',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Lane J.W.'},
#     {'ce:given-name': 'Amvrossios C.',
#      'preferred-name': {'ce:given-name': 'Amvrossios C.',
#       'ce:initials': 'A.C.',
#       'ce:surname': 'Bagtzoglou',
#       'ce:indexed-name': 'Bagtzoglou A.'},
#      '@seq': '3',
#      'ce:initials': 'A.C.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60022659',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60022659'},
#      'ce:surname': 'Bagtzoglou',
#      '@auid': '7003300087',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7003300087',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Bagtzoglou A.C.'},
#     {'ce:given-name': 'Dale D.',
#      'preferred-name': {'ce:given-name': 'Dale D.',
#       'ce:initials': 'D.D.',
#       'ce:surname': 'Werkema',
#       'ce:indexed-name': 'Werkema D.'},
#      '@seq': '4',
#      'ce:initials': 'D.D.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60021439',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60021439'},
#      'ce:surname': 'Werkema',
#      '@auid': '6603081105',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/6603081105',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Werkema D.D.'}]},
#   'url': 'https://api.elsevier.com/content/abstract/scopus_id/84978115007'},
#  {'scopus-eid': '2-s2.0-0036695720',
#   'citedby-count': '6',
#   'scopus-id': '0036695720',
#   '@_fa': 'true',
#   'volisspag': {'voliss': {'@volume': '54', '@issue': '8'},
#    'pagerange': {'@first': '38', '@last': '41'}},
#   'sourcetitle': 'International Water Power and Dam Construction',
#   '@id': '2',
#   'title': 'Experiencing the Teton dam failure',
#   'author-list': {'author': [{'ce:given-name': 'Leo A.',
#      'preferred-name': {'ce:given-name': 'Leo A.',
#       'ce:initials': 'L.A.',
#       'ce:surname': 'Busch',
#       'ce:indexed-name': 'Busch L.'},
#      '@seq': '1',
#      'ce:initials': 'L.A.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '101384271',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/101384271'},
#      'ce:surname': 'Busch',
#      '@auid': '7005463547',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7005463547',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Busch L.A.'}]},
#   'url': 'https://api.elsevier.com/content/abstract/scopus_id/0036695720'},
#  {'scopus-eid': '2-s2.0-0036609180',
#   'citedby-count': '14',
#   'scopus-id': '0036609180',
#   '@_fa': 'true',
#   'volisspag': {'voliss': {'@volume': '18', '@issue': '6'},
#    'pagerange': {'@first': '399', '@last': '409'}},
#   'sourcetitle': 'Communications in Numerical Methods in Engineering',
#   '@id': '3',
#   'title': 'Analysis of coupled seepage and temperature fields in concrete dam',
#   'ce:doi': '10.1002/cnm.498',
#   'author-list': {'author': [{'ce:given-name': 'Chai',
#      'preferred-name': {'ce:given-name': 'Chai',
#       'ce:initials': 'C.',
#       'ce:surname': 'Junrui',
#       'ce:indexed-name': 'Junrui C.'},
#      '@seq': '1',
#      'ce:initials': 'C.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60016521',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60016521'},
#      'ce:surname': 'Junrui',
#      '@auid': '23108840600',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/23108840600',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Junrui C.'},
#     {'ce:given-name': 'Chai',
#      'preferred-name': {'ce:given-name': 'Chai',
#       'ce:initials': 'C.',
#       'ce:surname': 'Junrui',
#       'ce:indexed-name': 'Junrui C.'},
#      '@seq': '1',
#      'ce:initials': 'C.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60016521',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60016521'},
#      'ce:surname': 'Junrui',
#      '@auid': '23108840600',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/23108840600',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Junrui C.'}]},
#   'url': 'https://api.elsevier.com/content/abstract/scopus_id/0036609180'},
#  {'scopus-eid': '2-s2.0-85007060782',
#   'citedby-count': '5',
#   'scopus-id': '85007060782',
#   '@_fa': 'true',
#   'volisspag': {'voliss': {'@volume': '16', '@issue': '1'},
#    'pagerange': {'@first': '50', '@last': '61'}},
#   'sourcetitle': 'Structural Health Monitoring',
#   '@id': '4',
#   'title': 'An experimental study: Fiber Bragg grating–hydrothermal cycling integration system for seepage monitoring of rockfill dams',
#   'ce:doi': '10.1177/1475921716661874',
#   'author-list': {'author': [{'ce:given-name': 'Jiang',
#      'preferred-name': {'ce:given-name': 'Jiang',
#       'ce:initials': 'J.',
#       'ce:surname': 'Chen',
#       'ce:indexed-name': 'Chen J.'},
#      '@seq': '1',
#      'ce:initials': 'J.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60016521',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60016521'},
#      'ce:surname': 'Chen',
#      '@auid': '9237998500',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/9237998500',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Chen J.'},
#     {'ce:given-name': 'Feng',
#      'preferred-name': {'ce:given-name': 'Feng',
#       'ce:initials': 'F.',
#       'ce:surname': 'Xiong',
#       'ce:indexed-name': 'Xiong F.'},
#      '@seq': '3',
#      'ce:initials': 'F.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60016521',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60016521'},
#      'ce:surname': 'Xiong',
#      '@auid': '55545861681',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/55545861681',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Xiong F.'},
#     {'ce:given-name': 'Qi',
#      'preferred-name': {'ce:given-name': 'Qi',
#       'ce:initials': 'Q.',
#       'ce:surname': 'Ge',
#       'ce:indexed-name': 'Ge Q.'},
#      '@seq': '4',
#      'ce:initials': 'Q.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60016521',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60016521'},
#      'ce:surname': 'Ge',
#      '@auid': '55236963200',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/55236963200',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Ge Q.'},
#     {'ce:given-name': 'Fei',
#      'preferred-name': {'ce:given-name': 'Fei',
#       'ce:initials': 'F.',
#       'ce:surname': 'Cheng',
#       'ce:indexed-name': 'Cheng F.'},
#      '@seq': '2',
#      'ce:initials': 'F.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60016521',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60016521'},
#      'ce:surname': 'Cheng',
#      '@auid': '54583295000',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/54583295000',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Cheng F.'},
#     {'ce:given-name': 'Shaojie',
#      'preferred-name': {'ce:given-name': 'Shaojie',
#       'ce:initials': 'S.',
#       'ce:surname': 'Zhang',
#       'ce:indexed-name': 'Zhang S.'},
#      '@seq': '5',
#      'ce:initials': 'S.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60020259',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60020259'},
#      'ce:surname': 'Zhang',
#      '@auid': '35249906100',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/35249906100',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Zhang S.'}]},
#   'url': 'https://api.elsevier.com/content/abstract/scopus_id/85007060782'},
#  {'scopus-eid': '2-s2.0-40449088905',
#   'citedby-count': '5',
#   'scopus-id': '40449088905',
#   '@_fa': 'true',
#   'volisspag': {'voliss': {'@issue': '175'}, 'pagerange': {'@first': '59'}},
#   'sourcetitle': 'Geotechnical Special Publication',
#   '@id': '5',
#   'title': 'Water leakage detection using optical fiber at the peribonka dam',
#   'ce:doi': '10.1061/40940(307)59',
#   'author-list': {'author': [{'ce:given-name': 'Alain',
#      'preferred-name': {'ce:given-name': 'Alain',
#       'ce:initials': 'A.',
#       'ce:surname': 'Coté',
#       'ce:indexed-name': 'Coté A.'},
#      '@seq': '1',
#      'ce:initials': 'A.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60022089',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60022089'},
#      'ce:surname': 'Coté',
#      '@auid': '57202663757',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/57202663757',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Cote A.'},
#     {'ce:given-name': 'Jean',
#      'preferred-name': {'ce:given-name': 'Jean',
#       'ce:initials': 'J.',
#       'ce:surname': 'Leduc',
#       'ce:indexed-name': 'Leduc J.'},
#      '@seq': '3',
#      'ce:initials': 'J.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60022089',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60022089'},
#      'ce:surname': 'Leduc',
#      '@auid': '7102688788',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7102688788',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Leduc J.'},
#     {'ce:given-name': 'Pierre',
#      'preferred-name': {'ce:given-name': 'Pierre',
#       'ce:initials': 'P.',
#       'ce:surname': 'Noël',
#       'ce:indexed-name': 'Noël P.'},
#      '@seq': '4',
#      'ce:initials': 'P.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60022089',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60022089'},
#      'ce:surname': 'Noël',
#      '@auid': '57197997962',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/57197997962',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Noel P.'},
#     {'ce:given-name': 'Réal',
#      'preferred-name': {'ce:given-name': 'Réal',
#       'ce:initials': 'R.',
#       'ce:surname': 'Beauchemin',
#       'ce:indexed-name': 'Beauchemin R.'},
#      '@seq': '5',
#      'ce:initials': 'R.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60022089',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60022089'},
#      'ce:surname': 'Beauchemin',
#      '@auid': '25421159800',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/25421159800',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Beauchemin R.'},
#     {'ce:given-name': 'Mathieu',
#      'preferred-name': {'ce:given-name': 'Mathieu',
#       'ce:initials': 'M.',
#       'ce:surname': 'Soares',
#       'ce:indexed-name': 'Soares M.'},
#      '@seq': '6',
#      'ce:initials': 'M.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60022089',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60022089'},
#      'ce:surname': 'Soares',
#      '@auid': '55418326400',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/55418326400',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Soares M.'},
#     {'ce:given-name': 'Benoit',
#      'preferred-name': {'ce:given-name': 'Benoit',
#       'ce:initials': 'B.',
#       'ce:surname': 'Carrier',
#       'ce:indexed-name': 'Carrier B.'},
#      '@seq': '2',
#      'ce:initials': 'B.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60022089',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60022089'},
#      'ce:surname': 'Carrier',
#      '@auid': '56971967900',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/56971967900',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Carrier B.'},
#     {'ce:given-name': 'Christian',
#      'preferred-name': {'ce:given-name': 'Christian',
#       'ce:initials': 'C.',
#       'ce:surname': 'Garneau',
#       'ce:indexed-name': 'Garneau C.'},
#      '@seq': '7',
#      'ce:initials': 'C.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60022089',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60022089'},
#      'ce:surname': 'Garneau',
#      '@auid': '6506113401',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/6506113401',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Garneau C.'},
#     {'ce:given-name': 'Richard',
#      'preferred-name': {'ce:given-name': 'Richard',
#       'ce:initials': 'R.',
#       'ce:surname': 'Gervais',
#       'ce:indexed-name': 'Gervais R.'},
#      '@seq': '8',
#      'ce:initials': 'R.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60022089',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60022089'},
#      'ce:surname': 'Gervais',
#      '@auid': '23970825800',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/23970825800',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Gervais R.'}]},
#   'url': 'https://api.elsevier.com/content/abstract/scopus_id/40449088905'},
#  {'scopus-eid': '2-s2.0-84906725860',
#   'citedby-count': '11',
#   'scopus-id': '84906725860',
#   '@_fa': 'true',
#   'volisspag': {'voliss': {'@volume': '13', '@issue': '5'},
#    'pagerange': {'@first': '562', '@last': '576'}},
#   'sourcetitle': 'Structural Health Monitoring',
#   '@id': '6',
#   'title': 'Monitoring and early detection of internal erosion: Distributed sensing and processing',
#   'ce:doi': '10.1177/1475921714532994',
#   'author-list': {'author': [{'ce:given-name': 'Amir A.',
#      'preferred-name': {'ce:given-name': 'Amir A.',
#       'ce:initials': 'A.A.',
#       'ce:surname': 'Khan',
#       'ce:indexed-name': 'Khan A.'},
#      '@seq': '1',
#      'ce:initials': 'A.A.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60059937',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60059937'},
#      'ce:surname': 'Khan',
#      '@auid': '55473387400',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/55473387400',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Khan A.A.'},
#     {'ce:given-name': 'Valeriu',
#      'preferred-name': {'ce:given-name': 'Valeriu',
#       'ce:initials': 'V.',
#       'ce:surname': 'Vrabie',
#       'ce:indexed-name': 'Vrabie V.'},
#      '@seq': '2',
#      'ce:initials': 'V.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60019394',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60019394'},
#      'ce:surname': 'Vrabie',
#      '@auid': '24391426800',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/24391426800',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Vrabie V.'},
#     {'ce:given-name': 'Yves-Laurent',
#      'preferred-name': {'ce:given-name': 'Yves Laurent',
#       'ce:initials': 'Y.L.',
#       'ce:surname': 'Beck',
#       'ce:indexed-name': 'Beck Y.'},
#      '@seq': '3',
#      'ce:initials': 'Y.-L.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60029873',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60029873'},
#      'ce:surname': 'Beck',
#      '@auid': '55639056100',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/55639056100',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Beck Y.-L.'},
#     {'ce:given-name': 'Guy',
#      'preferred-name': {'ce:given-name': 'Guy',
#       'ce:initials': 'G.',
#       'ce:surname': "D'Urso",
#       'ce:indexed-name': "D'Urso G."},
#      '@seq': '5',
#      'ce:initials': 'G.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60029873',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60029873'},
#      'ce:surname': "D'Urso",
#      '@auid': '24390476900',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/24390476900',
#      '@force-array': 'true',
#      'ce:indexed-name': "D'Urso G."},
#     {'ce:given-name': 'Jerome I.',
#      'preferred-name': {'ce:given-name': 'Jerome I.',
#       'ce:initials': 'J.I.',
#       'ce:surname': 'Mars',
#       'ce:indexed-name': 'Mars J.'},
#      '@seq': '4',
#      'ce:initials': 'J.I.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60104170',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60104170'},
#      'ce:surname': 'Mars',
#      '@auid': '7004216193',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7004216193',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Mars J.I.'}]},
#   'url': 'https://api.elsevier.com/content/abstract/scopus_id/84906725860'},
#  {'scopus-eid': '2-s2.0-84924222057',
#   'citedby-count': '97',
#   'scopus-id': '84924222057',
#   '@_fa': 'true',
#   'volisspag': {'voliss': {'@volume': '48', '@issue': '4'},
#    'pagerange': {'@first': '871', '@last': '906'}},
#   'sourcetitle': 'Materials and Structures/Materiaux et Constructions',
#   '@id': '7',
#   'title': 'Review: optical fiber sensors for civil engineering applications',
#   'ce:doi': '10.1617/s11527-013-0201-7',
#   'author-list': {'author': [{'ce:given-name': 'Christopher K. Y.',
#      'preferred-name': {'ce:given-name': 'Christopher K.Y.',
#       'ce:initials': 'C.K.Y.',
#       'ce:surname': 'Leung',
#       'ce:indexed-name': 'Leung C.'},
#      '@seq': '1',
#      'ce:initials': 'C.K.Y.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60008592',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60008592'},
#      'ce:surname': 'Leung',
#      '@auid': '7402612410',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7402612410',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Leung C.K.Y.'},
#     {'ce:given-name': 'Kai Tai',
#      'preferred-name': {'ce:given-name': 'Kai Tai',
#       'ce:initials': 'K.T.',
#       'ce:surname': 'Wan',
#       'ce:indexed-name': 'Wan K.'},
#      '@seq': '2',
#      'ce:initials': 'K.T.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '111145152',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/111145152'},
#      'ce:surname': 'Wan',
#      '@auid': '12765319800',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/12765319800',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Wan K.T.'},
#     {'ce:given-name': 'Daniele',
#      'preferred-name': {'ce:given-name': 'Daniele',
#       'ce:initials': 'D.',
#       'ce:surname': 'Inaudi',
#       'ce:indexed-name': 'Inaudi D.'},
#      '@seq': '3',
#      'ce:initials': 'D.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '113212510',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/113212510'},
#      'ce:surname': 'Inaudi',
#      '@auid': '7004603826',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7004603826',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Inaudi D.'},
#     {'ce:given-name': 'Xiaoyi',
#      'preferred-name': {'ce:given-name': 'Xiaoyi',
#       'ce:initials': 'X.',
#       'ce:surname': 'Bao',
#       'ce:indexed-name': 'Bao X.'},
#      '@seq': '4',
#      'ce:initials': 'X.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '106663407',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/106663407'},
#      'ce:surname': 'Bao',
#      '@auid': '7202850534',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7202850534',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Bao X.'},
#     {'ce:given-name': 'Wolfgang',
#      'preferred-name': {'ce:given-name': 'Wolfgang',
#       'ce:initials': 'W.',
#       'ce:surname': 'Habel',
#       'ce:indexed-name': 'Habel W.'},
#      '@seq': '5',
#      'ce:initials': 'W.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60072294',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60072294'},
#      'ce:surname': 'Habel',
#      '@auid': '55886721200',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/55886721200',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Habel W.'},
#     {'ce:given-name': 'Zhi',
#      'preferred-name': {'ce:given-name': 'Zhi',
#       'ce:initials': 'Z.',
#       'ce:surname': 'Zhou',
#       'ce:indexed-name': 'Zhou Z.'},
#      '@seq': '6',
#      'ce:initials': 'Z.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60019616',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60019616'},
#      'ce:surname': 'Zhou',
#      '@auid': '7406098352',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7406098352',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Zhou Z.'},
#     {'ce:given-name': 'Jinping',
#      'preferred-name': {'ce:given-name': 'Jinping',
#       'ce:initials': 'J.',
#       'ce:surname': 'Ou',
#       'ce:indexed-name': 'Ou J.'},
#      '@seq': '7',
#      'ce:initials': 'J.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60004538',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60004538'},
#      'ce:surname': 'Ou',
#      '@auid': '7202845830',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7202845830',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Ou J.'},
#     {'ce:given-name': 'Masoud',
#      'preferred-name': {'ce:given-name': 'Masoud',
#       'ce:initials': 'M.',
#       'ce:surname': 'Ghandehari',
#       'ce:indexed-name': 'Ghandehari M.'},
#      '@seq': '8',
#      'ce:initials': 'M.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60108318',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60108318'},
#      'ce:surname': 'Ghandehari',
#      '@auid': '7003584135',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7003584135',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Ghandehari M.'},
#     {'ce:given-name': 'Hwai Chung',
#      'preferred-name': {'ce:given-name': 'Hwai Chung',
#       'ce:initials': 'H.C.',
#       'ce:surname': 'Wu',
#       'ce:indexed-name': 'Wu H.'},
#      '@seq': '9',
#      'ce:initials': 'H.C.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60009408',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60009408'},
#      'ce:surname': 'Wu',
#      '@auid': '7405584876',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7405584876',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Wu H.C.'},
#     {'ce:given-name': 'Michio',
#      'preferred-name': {'ce:given-name': 'Michio',
#       'ce:initials': 'M.',
#       'ce:surname': 'Imai',
#       'ce:indexed-name': 'Imai M.'},
#      '@seq': '10',
#      'ce:initials': 'M.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60103562',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60103562'},
#      'ce:surname': 'Imai',
#      '@auid': '36436991400',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/36436991400',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Imai M.'}]},
#   'url': 'https://api.elsevier.com/content/abstract/scopus_id/84924222057'},
#  {'scopus-eid': '2-s2.0-84871386956',
#   'citedby-count': '3',
#   'scopus-id': '84871386956',
#   '@_fa': 'true',
#   'volisspag': {'voliss': {'@volume': '2012'}},
#   'sourcetitle': 'Advances in OptoElectronics',
#   '@id': '8',
#   'title': 'Multiplexed FBG monitoring system for forecasting coalmine water inrush disaster',
#   'article-number': '895723',
#   'ce:doi': '10.1155/2012/895723',
#   'author-list': {'author': [{'preferred-name': {'ce:given-name': 'B.',
#       'ce:initials': 'B.',
#       'ce:surname': 'Liu',
#       'ce:indexed-name': 'Liu B.'},
#      '@seq': '1',
#      'ce:initials': 'B.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60031031',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60031031'},
#      'ce:surname': 'Liu',
#      '@auid': '57192375308',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/57192375308',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Liu B.'},
#     {'preferred-name': {'ce:given-name': 'S. C.',
#       'ce:initials': 'S.C.',
#       'ce:surname': 'Li',
#       'ce:indexed-name': 'Li S.'},
#      '@seq': '2',
#      'ce:initials': 'S.C.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60031031',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60031031'},
#      'ce:surname': 'Li',
#      '@auid': '24450726200',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/24450726200',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Li S.C.'},
#     {'preferred-name': {'ce:given-name': 'L. C.',
#       'ce:initials': 'L.C.',
#       'ce:surname': 'Nie',
#       'ce:indexed-name': 'Nie L.'},
#      '@seq': '5',
#      'ce:initials': 'L.C.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60031031',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60031031'},
#      'ce:surname': 'Nie',
#      '@auid': '36657456700',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/36657456700',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Nie L.C.'},
#     {'preferred-name': {'ce:given-name': 'J.',
#       'ce:initials': 'J.',
#       'ce:surname': 'Wang',
#       'ce:indexed-name': 'Wang J.'},
#      '@seq': '3',
#      'ce:initials': 'J.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60031031',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60031031'},
#      'ce:surname': 'Wang',
#      '@auid': '7701312763',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7701312763',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Wang J.'},
#     {'preferred-name': {'ce:given-name': 'Q. M.',
#       'ce:initials': 'Q.M.',
#       'ce:surname': 'Sui',
#       'ce:indexed-name': 'Sui Q.'},
#      '@seq': '4',
#      'ce:initials': 'Q.M.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60031031',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60031031'},
#      'ce:surname': 'Sui',
#      '@auid': '15840475500',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/15840475500',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Sui Q.M.'},
#     {'preferred-name': {'ce:given-name': 'Z. F.',
#       'ce:initials': 'Z.F.',
#       'ce:surname': 'Wang',
#       'ce:indexed-name': 'Wang Z.'},
#      '@seq': '6',
#      'ce:initials': 'Z.F.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60031031',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60031031'},
#      'ce:surname': 'Wang',
#      '@auid': '56106045500',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/56106045500',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Wang Z.F.'},
#     {'preferred-name': {'ce:given-name': 'J.',
#       'ce:initials': 'J.',
#       'ce:surname': 'Wang',
#       'ce:indexed-name': 'Wang J.'},
#      '@seq': '3',
#      'ce:initials': 'J.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60033100',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#      'ce:surname': 'Wang',
#      '@auid': '7701312763',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7701312763',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Wang J.'}]},
#   'url': 'https://api.elsevier.com/content/abstract/scopus_id/84871386956'},
#  {'scopus-eid': '2-s2.0-84868014007',
#   'citedby-count': '30',
#   'scopus-id': '84868014007',
#   '@_fa': 'true',
#   'volisspag': {'voliss': {'@volume': '21', '@issue': '11'}},
#   'sourcetitle': 'Smart Materials and Structures',
#   '@id': '9',
#   'title': 'Application of a distributed optical fiber sensing technique in monitoring the stress of precast piles',
#   'article-number': '115011',
#   'ce:doi': '10.1088/0964-1726/21/11/115011',
#   'author-list': {'author': [{'preferred-name': {'ce:given-name': 'Y.',
#       'ce:initials': 'Y.',
#       'ce:surname': 'Lu',
#       'ce:indexed-name': 'Lu Y.'},
#      '@seq': '1',
#      'ce:initials': 'Y.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60033100',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#      'ce:surname': 'Lu',
#      '@auid': '23393022800',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/23393022800',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Lu Y.'},
#     {'preferred-name': {'ce:given-name': 'B.',
#       'ce:initials': 'B.',
#       'ce:surname': 'Shi',
#       'ce:indexed-name': 'Shi B.'},
#      '@seq': '2',
#      'ce:initials': 'B.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60033100',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#      'ce:surname': 'Shi',
#      '@auid': '7402545779',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7402545779',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Shi B.'},
#     {'preferred-name': {'ce:given-name': 'G. Q.',
#       'ce:initials': 'G.Q.',
#       'ce:surname': 'Wei',
#       'ce:indexed-name': 'Wei G.'},
#      '@seq': '3',
#      'ce:initials': 'G.Q.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60033100',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#      'ce:surname': 'Wei',
#      '@auid': '24386049800',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/24386049800',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Wei G.Q.'},
#     {'preferred-name': {'ce:given-name': 'D.',
#       'ce:initials': 'D.',
#       'ce:surname': 'Zhang',
#       'ce:indexed-name': 'Zhang D.'},
#      '@seq': '5',
#      'ce:initials': 'D.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60033100',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#      'ce:surname': 'Zhang',
#      '@auid': '55717553100',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/55717553100',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Zhang D.'},
#     {'preferred-name': {'ce:given-name': 'S. E.',
#       'ce:initials': 'S.E.',
#       'ce:surname': 'Chen',
#       'ce:indexed-name': 'Chen S.'},
#      '@seq': '4',
#      'ce:initials': 'S.E.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60006951',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60006951'},
#      'ce:surname': 'Chen',
#      '@auid': '14033942200',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/14033942200',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Chen S.E.'}]},
#   'url': 'https://api.elsevier.com/content/abstract/scopus_id/84868014007'},
#  {'scopus-eid': '2-s2.0-84855925873',
#   'citedby-count': '58',
#   'scopus-id': '84855925873',
#   '@_fa': 'true',
#   'volisspag': {'voliss': {'@volume': '137', '@issue': '12'},
#    'pagerange': {'@first': '1236', '@last': '1243'}},
#   'sourcetitle': 'Journal of Geotechnical and Geoenvironmental Engineering',
#   '@id': '10',
#   'title': 'Performance monitoring of a secant-piled wall using distributed fiber optic strain sensing',
#   'ce:doi': '10.1061/(ASCE)GT.1943-5606.0000543',
#   'author-list': {'author': [{'ce:given-name': 'Hisham',
#      'preferred-name': {'ce:given-name': 'Hisham',
#       'ce:initials': 'H.',
#       'ce:surname': 'Mohamad',
#       'ce:indexed-name': 'Mohamad H.'},
#      '@seq': '1',
#      'ce:initials': 'H.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60021005',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60021005'},
#      'ce:surname': 'Mohamad',
#      '@auid': '23971181600',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/23971181600',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Mohamad H.'},
#     {'ce:given-name': 'Kenichi',
#      'preferred-name': {'ce:given-name': 'Kenichi',
#       'ce:initials': 'K.',
#       'ce:surname': 'Soga',
#       'ce:indexed-name': 'Soga K.'},
#      '@seq': '2',
#      'ce:initials': 'K.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60031101',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60031101'},
#      'ce:surname': 'Soga',
#      '@auid': '7102442890',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7102442890',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Soga K.'},
#     {'ce:given-name': 'Adam',
#      'preferred-name': {'ce:given-name': 'Adam',
#       'ce:initials': 'A.',
#       'ce:surname': 'Pellew',
#       'ce:indexed-name': 'Pellew A.'},
#      '@seq': '3',
#      'ce:initials': 'A.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '112601714',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/112601714'},
#      'ce:surname': 'Pellew',
#      '@auid': '54897924000',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/54897924000',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Pellew A.'},
#     {'ce:given-name': 'Peter J.',
#      'preferred-name': {'ce:given-name': 'Peter J.',
#       'ce:initials': 'P.J.',
#       'ce:surname': 'Bennett',
#       'ce:indexed-name': 'Bennett P.'},
#      '@seq': '4',
#      'ce:initials': 'P.J.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60031101',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60031101'},
#      'ce:surname': 'Bennett',
#      '@auid': '24309693700',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/24309693700',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Bennett P.J.'}]},
#   'url': 'https://api.elsevier.com/content/abstract/scopus_id/84855925873'},
#  {'scopus-eid': '2-s2.0-36749072655',
#   'citedby-count': '27',
#   'scopus-id': '36749072655',
#   '@_fa': 'true',
#   'volisspag': {'voliss': {'@volume': '18', '@issue': '10'},
#    'pagerange': {'@first': '3202', '@last': '3210'}},
#   'sourcetitle': 'Measurement Science and Technology',
#   '@id': '11',
#   'title': 'Application of a distributed fibre optic strain sensing system to monitoring changes in the state of an underground mine',
#   'ce:doi': '10.1088/0957-0233/18/10/S23',
#   'author-list': {'author': [{'ce:given-name': 'Hiroshi',
#      'preferred-name': {'ce:given-name': 'Hiroshi',
#       'ce:initials': 'H.',
#       'ce:surname': 'Naruse',
#       'ce:indexed-name': 'Naruse H.'},
#      '@seq': '1',
#      'ce:initials': 'H.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60018873',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60018873'},
#      'ce:surname': 'Naruse',
#      '@auid': '7102785206',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7102785206',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Naruse H.'},
#     {'ce:given-name': 'Hideki',
#      'preferred-name': {'ce:given-name': 'Hideki',
#       'ce:initials': 'H.',
#       'ce:surname': 'Uehara',
#       'ce:indexed-name': 'Uehara H.'},
#      '@seq': '2',
#      'ce:initials': 'H.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60025555',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60025555'},
#      'ce:surname': 'Uehara',
#      '@auid': '7202112265',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7202112265',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Uehara H.'},
#     {'ce:given-name': 'Taishi',
#      'preferred-name': {'ce:given-name': 'Taishi',
#       'ce:initials': 'T.',
#       'ce:surname': 'Deguchi',
#       'ce:indexed-name': 'Deguchi T.'},
#      '@seq': '3',
#      'ce:initials': 'T.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60025555',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60025555'},
#      'ce:surname': 'Deguchi',
#      '@auid': '7201725538',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7201725538',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Deguchi T.'},
#     {'ce:given-name': 'Kazuhiko',
#      'preferred-name': {'ce:given-name': 'Kazuhiko',
#       'ce:initials': 'K.',
#       'ce:surname': 'Fujihashi',
#       'ce:indexed-name': 'Fujihashi K.'},
#      '@seq': '4',
#      'ce:initials': 'K.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60025555',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60025555'},
#      'ce:surname': 'Fujihashi',
#      '@auid': '22034495400',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/22034495400',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Fujihashi K.'},
#     {'ce:given-name': 'Masatoshi',
#      'preferred-name': {'ce:given-name': 'Masatoshi',
#       'ce:initials': 'M.',
#       'ce:surname': 'Onishi',
#       'ce:indexed-name': 'Onishi M.'},
#      '@seq': '5',
#      'ce:initials': 'M.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60093328',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60093328'},
#      'ce:surname': 'Onishi',
#      '@auid': '23029117300',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/23029117300',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Onishi M.'},
#     {'ce:given-name': 'Raul',
#      'preferred-name': {'ce:given-name': 'Raul',
#       'ce:initials': 'R.',
#       'ce:surname': 'Espinoza',
#       'ce:indexed-name': 'Espinoza R.'},
#      '@seq': '6',
#      'ce:initials': 'R.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60004849',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60004849'},
#      'ce:surname': 'Espinoza',
#      '@auid': '36886510600',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/36886510600',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Espinoza R.'},
#     {'ce:given-name': 'Cesar',
#      'preferred-name': {'ce:given-name': 'Cesar',
#       'ce:initials': 'C.',
#       'ce:surname': 'Guzman',
#       'ce:indexed-name': 'Guzman C.'},
#      '@seq': '7',
#      'ce:initials': 'C.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60004849',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60004849'},
#      'ce:surname': 'Guzman',
#      '@auid': '57198172982',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/57198172982',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Guzman C.'},
#     {'ce:given-name': 'Cesar',
#      'preferred-name': {'ce:given-name': 'Cesar',
#       'ce:initials': 'C.',
#       'ce:surname': 'Pardo',
#       'ce:indexed-name': 'Pardo C.'},
#      '@seq': '8',
#      'ce:initials': 'C.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60004849',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60004849'},
#      'ce:surname': 'Pardo',
#      '@auid': '23029104500',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/23029104500',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Pardo C.'},
#     {'ce:given-name': 'Cesar',
#      'preferred-name': {'ce:given-name': 'Cesar',
#       'ce:initials': 'C.',
#       'ce:surname': 'Ortega',
#       'ce:indexed-name': 'Ortega C.'},
#      '@seq': '9',
#      'ce:initials': 'C.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60004849',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60004849'},
#      'ce:surname': 'Ortega',
#      '@auid': '23029088400',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/23029088400',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Ortega C.'},
#     {'ce:given-name': 'Manuel',
#      'preferred-name': {'ce:given-name': 'Manuel',
#       'ce:initials': 'M.',
#       'ce:surname': 'Pinto',
#       'ce:indexed-name': 'Pinto M.'},
#      '@seq': '10',
#      'ce:initials': 'M.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60004849',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60004849'},
#      'ce:surname': 'Pinto',
#      '@auid': '57198389447',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/57198389447',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Pinto M.'}]},
#   'url': 'https://api.elsevier.com/content/abstract/scopus_id/36749072655'},
#  {'scopus-eid': '2-s2.0-77951566656',
#   'citedby-count': '233',
#   'scopus-id': '77951566656',
#   '@_fa': 'true',
#   'volisspag': {'voliss': {'@volume': '9', '@issue': '3'},
#    'pagerange': {'@first': '219', '@last': '231'}},
#   'sourcetitle': 'Structural Health Monitoring',
#   '@id': '12',
#   'title': 'Structural health monitoring in mainland china: Review and future trends',
#   'ce:doi': '10.1177/1475921710365269',
#   'author-list': {'author': [{'ce:given-name': 'Jinping',
#      'preferred-name': {'ce:given-name': 'Jinping',
#       'ce:initials': 'J.',
#       'ce:surname': 'Ou',
#       'ce:indexed-name': 'Ou J.'},
#      '@seq': '1',
#      'ce:initials': 'J.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60004538',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60004538'},
#      'ce:surname': 'Ou',
#      '@auid': '7202845830',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7202845830',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Ou J.'},
#     {'ce:given-name': 'Jinping',
#      'preferred-name': {'ce:given-name': 'Jinping',
#       'ce:initials': 'J.',
#       'ce:surname': 'Ou',
#       'ce:indexed-name': 'Ou J.'},
#      '@seq': '1',
#      'ce:initials': 'J.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60019616',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60019616'},
#      'ce:surname': 'Ou',
#      '@auid': '7202845830',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7202845830',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Ou J.'},
#     {'ce:given-name': 'Hui',
#      'preferred-name': {'ce:given-name': 'Hui',
#       'ce:initials': 'H.',
#       'ce:surname': 'Li',
#       'ce:indexed-name': 'Li H.'},
#      '@seq': '2',
#      'ce:initials': 'H.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60019616',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60019616'},
#      'ce:surname': 'Li',
#      '@auid': '57202721115',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/57202721115',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Li H.'}]},
#   'url': 'https://api.elsevier.com/content/abstract/scopus_id/77951566656'},
#  {'scopus-eid': '2-s2.0-84907818061',
#   'citedby-count': '27',
#   'scopus-id': '84907818061',
#   '@_fa': 'true',
#   'volisspag': {'voliss': {'@volume': '58'},
#    'pagerange': {'@first': '207', '@last': '214'}},
#   'sourcetitle': 'Measurement: Journal of the International Measurement Confederation',
#   '@id': '13',
#   'title': 'A review of previous studies on the applications of optical fiber sensors in geotechnical health monitoring',
#   'ce:doi': '10.1016/j.measurement.2014.08.013',
#   'author-list': {'author': [{'ce:given-name': 'Hua-Fu',
#      'preferred-name': {'ce:given-name': 'Hua Fu',
#       'ce:initials': 'H.F.',
#       'ce:surname': 'Pei',
#       'ce:indexed-name': 'Pei H.'},
#      '@seq': '1',
#      'ce:initials': 'H.-F.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60019616',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60019616'},
#      'ce:surname': 'Pei',
#      '@auid': '36444934100',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/36444934100',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Pei H.-F.'},
#     {'ce:given-name': 'Jun',
#      'preferred-name': {'ce:given-name': 'Jun',
#       'ce:initials': 'J.',
#       'ce:surname': 'Teng',
#       'ce:indexed-name': 'Teng J.'},
#      '@seq': '2',
#      'ce:initials': 'J.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60019616',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60019616'},
#      'ce:surname': 'Teng',
#      '@auid': '7202560206',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7202560206',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Teng J.'},
#     {'ce:given-name': 'Rui',
#      'preferred-name': {'ce:given-name': 'Rui',
#       'ce:initials': 'R.',
#       'ce:surname': 'Chen',
#       'ce:indexed-name': 'Chen R.'},
#      '@seq': '4',
#      'ce:initials': 'R.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60019616',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60019616'},
#      'ce:surname': 'Chen',
#      '@auid': '55628525427',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/55628525427',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Chen R.'},
#     {'ce:given-name': 'Jian-Hua',
#      'preferred-name': {'ce:given-name': 'Jian Hua',
#       'ce:initials': 'J.H.',
#       'ce:surname': 'Yin',
#       'ce:indexed-name': 'Yin J.'},
#      '@seq': '3',
#      'ce:initials': 'J.-H.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60008928',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60008928'},
#      'ce:surname': 'Yin',
#      '@auid': '7401693397',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7401693397',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Yin J.-H.'}]},
#   'url': 'https://api.elsevier.com/content/abstract/scopus_id/84907818061'},
#  {'scopus-eid': '2-s2.0-84976598255',
#   'citedby-count': '20',
#   'scopus-id': '84976598255',
#   '@_fa': 'true',
#   'volisspag': {'voliss': {'@volume': '52', '@issue': '6'},
#    'pagerange': {'@first': '4486', '@last': '4503'}},
#   'sourcetitle': 'Water Resources Research',
#   '@id': '14',
#   'title': 'Combined use of thermal methods and seepage meters to efficiently locate, quantify, and monitor focused groundwater discharge to a sand-bed stream',
#   'ce:doi': '10.1002/2016WR018808',
#   'author-list': {'author': [{'ce:given-name': 'Donald O.',
#      'preferred-name': {'ce:given-name': 'Donald O.',
#       'ce:initials': 'D.O.',
#       'ce:surname': 'Rosenberry',
#       'ce:indexed-name': 'Rosenberry D.'},
#      '@seq': '1',
#      'ce:initials': 'D.O.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60011347',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60011347'},
#      'ce:surname': 'Rosenberry',
#      '@auid': '6701757807',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/6701757807',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Rosenberry D.O.'},
#     {'ce:given-name': 'Martin A.',
#      'preferred-name': {'ce:given-name': 'Martin A.',
#       'ce:initials': 'M.A.',
#       'ce:surname': 'Briggs',
#       'ce:indexed-name': 'Briggs M.'},
#      '@seq': '2',
#      'ce:initials': 'M.A.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60011347',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60011347'},
# ...
#   '@id': '18',
#   'title': 'Flume testing of seepage velocity monitoring using optic fiber distributed temperature sensing for embankments',
#   'ce:doi': '10.1108/SR-04-2015-0065',
#   'author-list': {'author': [{'ce:given-name': 'Chunhong',
#      'preferred-name': {'ce:given-name': 'Chunhong',
#       'ce:initials': 'C.',
#       'ce:surname': 'Wang',
#       'ce:indexed-name': 'Wang C.'},
#      '@seq': '1',
#      'ce:initials': 'C.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60021783',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60021783'},
#      'ce:surname': 'Wang',
#      '@auid': '57188707310',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/57188707310',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Wang C.'},
#     {'ce:given-name': 'Jihong',
#      'preferred-name': {'ce:given-name': 'Jihong',
#       'ce:initials': 'J.',
#       'ce:surname': 'Chen',
#       'ce:indexed-name': 'Chen J.'},
#      '@seq': '2',
#      'ce:initials': 'J.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60021783',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60021783'},
#      'ce:surname': 'Chen',
#      '@auid': '57188710464',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/57188710464',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Chen J.'},
#     {'ce:given-name': 'Jin',
#      'preferred-name': {'ce:given-name': 'Jin',
#       'ce:initials': 'J.',
#       'ce:surname': 'Wang',
#       'ce:indexed-name': 'Wang J.'},
#      '@seq': '3',
#      'ce:initials': 'J.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60021783',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60021783'},
#      'ce:surname': 'Wang',
#      '@auid': '57188712439',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/57188712439',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Wang J.'},
#     {'ce:given-name': 'Jianping',
#      'preferred-name': {'ce:given-name': 'Jianping',
#       'ce:initials': 'J.',
#       'ce:surname': 'Chen',
#       'ce:indexed-name': 'Chen J.'},
#      '@seq': '4',
#      'ce:initials': 'J.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60021783',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60021783'},
#      'ce:surname': 'Chen',
#      '@auid': '57188710475',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/57188710475',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Chen J.'}]},
#   'url': 'https://api.elsevier.com/content/abstract/scopus_id/84962382655'},
#  {'scopus-eid': '2-s2.0-84878031896',
#   'citedby-count': '10',
#   'scopus-id': '84878031896',
#   '@_fa': 'true',
#   'volisspag': {'voliss': {'@volume': '36', '@issue': '3'}},
#   'sourcetitle': 'Geotechnical Testing Journal',
#   '@id': '19',
#   'title': 'Experimental study of the applications of fiber optic distributed temperature sensors in detecting seepage in soils',
#   'ce:doi': '10.1520/GTJ20120096',
#   'author-list': {'author': [{'ce:given-name': 'Henglin',
#      'preferred-name': {'ce:given-name': 'Henglin',
#       'ce:initials': 'H.',
#       'ce:surname': 'Xiao',
#       'ce:indexed-name': 'Xiao H.'},
#      '@seq': '1',
#      'ce:initials': 'H.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60108756',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60108756'},
#      'ce:surname': 'Xiao',
#      '@auid': '7401565435',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7401565435',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Xiao H.'},
#     {'ce:given-name': 'Jie',
#      'preferred-name': {'ce:given-name': 'Jie',
#       'ce:initials': 'J.',
#       'ce:surname': 'Huang',
#       'ce:indexed-name': 'Huang J.'},
#      '@seq': '2',
#      'ce:initials': 'J.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60003212',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60003212'},
#      'ce:surname': 'Huang',
#      '@auid': '55742397700',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/55742397700',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Huang J.'}]},
#   'url': 'https://api.elsevier.com/content/abstract/scopus_id/84878031896'},
#  {'scopus-eid': '2-s2.0-85027924941',
#   'citedby-count': '10',
#   'scopus-id': '85027924941',
#   '@_fa': 'true',
#   'volisspag': {'voliss': {'@volume': '186'},
#    'pagerange': {'@first': '100', '@last': '104'}},
#   'sourcetitle': 'Engineering Geology',
#   '@id': '20',
#   'title': 'A quantitative monitoring technology for seepage in slopes using DTS',
#   'ce:doi': '10.1016/j.enggeo.2015.01.001',
#   'author-list': {'author': [{'ce:given-name': 'Jun-Fan',
#      'preferred-name': {'ce:given-name': 'Jun Fan',
#       'ce:initials': 'J.F.',
#       'ce:surname': 'Yan',
#       'ce:indexed-name': 'Yan J.'},
#      '@seq': '1',
#      'ce:initials': 'J.-F.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60033100',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#      'ce:surname': 'Yan',
#      '@auid': '55668100800',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/55668100800',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Yan J.-F.'},
#     {'ce:given-name': 'Bin',
#      'preferred-name': {'ce:given-name': 'Bin',
#       'ce:initials': 'B.',
#       'ce:surname': 'Shi',
#       'ce:indexed-name': 'Shi B.'},
#      '@seq': '2',
#      'ce:initials': 'B.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60033100',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#      'ce:surname': 'Shi',
#      '@auid': '7402545779',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7402545779',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Shi B.'},
#     {'ce:given-name': 'Hong-Hu',
#      'preferred-name': {'ce:given-name': 'Hong Hu',
#       'ce:initials': 'H.H.',
#       'ce:surname': 'Zhu',
#       'ce:indexed-name': 'Zhu H.'},
#      '@seq': '3',
#      'ce:initials': 'H.-H.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60033100',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#      'ce:surname': 'Zhu',
#      '@auid': '12140186000',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/12140186000',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Zhu H.-H.'},
#     {'ce:given-name': 'Bao-Jun',
#      'preferred-name': {'ce:given-name': 'Bao Jun',
#       'ce:initials': 'B.J.',
#       'ce:surname': 'Wang',
#       'ce:indexed-name': 'Wang B.'},
#      '@seq': '4',
#      'ce:initials': 'B.-J.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60033100',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#      'ce:surname': 'Wang',
#      '@auid': '57188823130',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/57188823130',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Wang B.-J.'},
#     {'ce:given-name': 'Ding-Feng',
#      'preferred-name': {'ce:given-name': 'Ding Feng',
#       'ce:initials': 'D.F.',
#       'ce:surname': 'Cao',
#       'ce:indexed-name': 'Cao D.'},
#      '@seq': '6',
#      'ce:initials': 'D.-F.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60033100',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#      'ce:surname': 'Cao',
#      '@auid': '56184645000',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/56184645000',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Cao D.-F.'},
#     {'ce:given-name': 'Guang-Qing',
#      'preferred-name': {'ce:given-name': 'Guang Qing',
#       'ce:initials': 'G.Q.',
#       'ce:surname': 'Wei',
#       'ce:indexed-name': 'Wei G.'},
#      '@seq': '5',
#      'ce:initials': 'G.-Q.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '114724446',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/114724446'},
#      'ce:surname': 'Wei',
#      '@auid': '24386049800',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/24386049800',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Wei G.-Q.'}]},
#   'url': 'https://api.elsevier.com/content/abstract/scopus_id/85027924941'},
#  {'scopus-eid': '2-s2.0-84906237126',
#   'citedby-count': '35',
#   'scopus-id': '84906237126',
#   '@_fa': 'true',
#   'volisspag': {'voliss': {'@volume': '23', '@issue': '9'}},
#   'sourcetitle': 'Smart Materials and Structures',
#   '@id': '21',
#   'title': 'Fiber Bragg grating-based performance monitoring of a slope model subjected to seepage',
#   'article-number': '095027',
#   'ce:doi': '10.1088/0964-1726/23/9/095027',
#   'author-list': {'author': [{'ce:given-name': 'Hong-Hu',
#      'preferred-name': {'ce:given-name': 'Hong Hu',
#       'ce:initials': 'H.H.',
#       'ce:surname': 'Zhu',
#       'ce:indexed-name': 'Zhu H.'},
#      '@seq': '1',
#      'ce:initials': 'H.-H.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60033100',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#      'ce:surname': 'Zhu',
#      '@auid': '12140186000',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/12140186000',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Zhu H.-H.'},
#     {'ce:given-name': 'Bin',
#      'preferred-name': {'ce:given-name': 'Bin',
#       'ce:initials': 'B.',
#       'ce:surname': 'Shi',
#       'ce:indexed-name': 'Shi B.'},
#      '@seq': '2',
#      'ce:initials': 'B.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60033100',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#      'ce:surname': 'Shi',
#      '@auid': '7402545779',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7402545779',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Shi B.'},
#     {'ce:given-name': 'Jun-Fan',
#      'preferred-name': {'ce:given-name': 'Jun Fan',
#       'ce:initials': 'J.F.',
#       'ce:surname': 'Yan',
#       'ce:indexed-name': 'Yan J.'},
#      '@seq': '3',
#      'ce:initials': 'J.-F.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60033100',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#      'ce:surname': 'Yan',
#      '@auid': '55668100800',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/55668100800',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Yan J.-F.'},
#     {'ce:given-name': 'Cheng-Cheng',
#      'preferred-name': {'ce:given-name': 'Cheng Cheng',
#       'ce:initials': 'C.C.',
#       'ce:surname': 'Zhang',
#       'ce:indexed-name': 'Zhang C.'},
#      '@seq': '5',
#      'ce:initials': 'C.-C.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60033100',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#      'ce:surname': 'Zhang',
#      '@auid': '55628533917',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/55628533917',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Zhang C.-C.'},
#     {'ce:given-name': 'Bao-Jun',
#      'preferred-name': {'ce:given-name': 'Bao Jun',
#       'ce:initials': 'B.J.',
#       'ce:surname': 'Wang',
#       'ce:indexed-name': 'Wang B.'},
#      '@seq': '6',
#      'ce:initials': 'B.-J.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60033100',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60033100'},
#      'ce:surname': 'Wang',
#      '@auid': '57188823130',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/57188823130',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Wang B.-J.'},
#     {'ce:given-name': 'Jie',
#      'preferred-name': {'ce:given-name': 'Jie',
#       'ce:initials': 'J.',
#       'ce:surname': 'Zhang',
#       'ce:indexed-name': 'Zhang J.'},
#      '@seq': '4',
#      'ce:initials': 'J.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60073652',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60073652'},
#      'ce:surname': 'Zhang',
#      '@auid': '55934252000',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/55934252000',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Zhang J.'}]},
#   'url': 'https://api.elsevier.com/content/abstract/scopus_id/84906237126'},
#  {'scopus-eid': '2-s2.0-79955364443',
#   'citedby-count': '7',
#   'scopus-id': '79955364443',
#   '@_fa': 'true',
#   'volisspag': {'voliss': {'@volume': '8'},
#    'pagerange': {'@first': '520', '@last': '526'}},
#   'sourcetitle': 'Procedia Engineering',
#   '@id': '22',
#   'title': 'Safety inspection strategy for earth embankment dams using fully distributed sensing',
#   'ce:doi': '10.1016/j.proeng.2011.03.094',
#   'author-list': {'author': [{'ce:given-name': 'Pingyu',
#      'preferred-name': {'ce:given-name': 'Pingyu',
#       'ce:initials': 'P.',
#       'ce:surname': 'Zhu',
#       'ce:indexed-name': 'Zhu P.'},
#      '@seq': '1',
#      'ce:initials': 'P.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60024617',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60024617'},
#      'ce:surname': 'Zhu',
#      '@auid': '7202169460',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/7202169460',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Zhu P.'},
#     {'preferred-name': {'ce:given-name': 'Y.',
#       'ce:initials': 'Y.',
#       'ce:surname': 'Zhou',
#       'ce:indexed-name': 'Zhou Y.'},
#      '@seq': '3',
#      'ce:initials': 'Y.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60024617',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60024617'},
#      'ce:surname': 'Zhou',
#      '@auid': '35209382100',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/35209382100',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Zhou Y.'},
#     {'preferred-name': {'ce:given-name': 'G. L.',
#       'ce:initials': 'G.L.',
#       'ce:surname': 'Jiang',
#       'ce:indexed-name': 'Jiang G.'},
#      '@seq': '4',
#      'ce:initials': 'G.L.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60024617',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60024617'},
#      'ce:surname': 'Jiang',
#      '@auid': '35204964900',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/35204964900',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Jiang G.L.'},
#     {'preferred-name': {'ce:given-name': 'Y. B.',
#       'ce:initials': 'Y.B.',
#       'ce:surname': 'Leng',
#       'ce:indexed-name': 'Leng Y.'},
#      '@seq': '2',
#      'ce:initials': 'Y.B.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60081483',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60081483'},
#      'ce:surname': 'Leng',
#      '@auid': '16205061800',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/16205061800',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Leng Y.B.'},
#     {'preferred-name': {'ce:given-name': 'Y.',
#       'ce:initials': 'Y.',
#       'ce:surname': 'Zhou',
#       'ce:indexed-name': 'Zhou Y.'},
#      '@seq': '3',
#      'ce:initials': 'Y.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60081483',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60081483'},
#      'ce:surname': 'Zhou',
#      '@auid': '35209382100',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/35209382100',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Zhou Y.'},
#     {'preferred-name': {'ce:given-name': 'G. L.',
#       'ce:initials': 'G.L.',
#       'ce:surname': 'Jiang',
#       'ce:indexed-name': 'Jiang G.'},
#      '@seq': '4',
#      'ce:initials': 'G.L.',
#      '@_fa': 'true',
#      'affiliation': {'@id': '60081483',
#       '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60081483'},
#      'ce:surname': 'Jiang',
#      '@auid': '35204964900',
#      'author-url': 'https://api.elsevier.com/content/author/author_id/35204964900',
#      '@force-array': 'true',
#      'ce:indexed-name': 'Jiang G.L.'}]},
#   'url': 'https://api.elsevier.com/content/abstract/scopus_id/79955364443'}]

# %%
reference_0 = json['abstracts-retrieval-response']['references']['reference'][0]
reference_0
# Out:
# {'scopus-eid': '2-s2.0-84978115007',
#  'citedby-count': '12',
#  'scopus-id': '84978115007',
#  '@_fa': 'true',
#  'volisspag': {'voliss': {'@volume': '52', '@issue': '7'},
#   'pagerange': {'@first': '5179', '@last': '5194'}},
#  'sourcetitle': 'Water Resources Research',
#  '@id': '1',
#  'title': 'Actively heated high-resolution fiber-optic-distributed temperature sensing to quantify streambed flow dynamics in zones of strong groundwater upwelling',
#  'ce:doi': '10.1002/2015WR018219',
#  'author-list': {'author': [{'ce:given-name': 'Martin A.',
#     'preferred-name': {'ce:given-name': 'Martin A.',
#      'ce:initials': 'M.A.',
#      'ce:surname': 'Briggs',
#      'ce:indexed-name': 'Briggs M.'},
#     '@seq': '1',
#     'ce:initials': 'M.A.',
#     '@_fa': 'true',
#     'affiliation': {'@id': '60011347',
#      '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60011347'},
#     'ce:surname': 'Briggs',
#     '@auid': '36162817300',
#     'author-url': 'https://api.elsevier.com/content/author/author_id/36162817300',
#     '@force-array': 'true',
#     'ce:indexed-name': 'Briggs M.A.'},
#    {'ce:given-name': 'Sean F.',
#     'preferred-name': {'ce:given-name': 'Sean F.',
#      'ce:initials': 'S.F.',
#      'ce:surname': 'Buckley',
#      'ce:indexed-name': 'Buckley S.'},
#     '@seq': '2',
#     'ce:initials': 'S.F.',
#     '@_fa': 'true',
#     'affiliation': {'@id': '60011347',
#      '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60011347'},
#     'ce:surname': 'Buckley',
#     '@auid': '55389924800',
#     'author-url': 'https://api.elsevier.com/content/author/author_id/55389924800',
#     '@force-array': 'true',
#     'ce:indexed-name': 'Buckley S.F.'},
#    {'ce:given-name': 'John W.',
#     'preferred-name': {'ce:given-name': 'John W.',
#      'ce:initials': 'J.W.',
#      'ce:surname': 'Lane',
#      'ce:indexed-name': 'Lane J.'},
#     '@seq': '5',
#     'ce:initials': 'J.W.',
#     '@_fa': 'true',
#     'affiliation': {'@id': '60011347',
#      '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60011347'},
#     'ce:surname': 'Lane',
#     '@auid': '7401532379',
#     'ce:suffix': 'Jr.',
#     'author-url': 'https://api.elsevier.com/content/author/author_id/7401532379',
#     '@force-array': 'true',
#     'ce:indexed-name': 'Lane J.W.'},
#    {'ce:given-name': 'Amvrossios C.',
#     'preferred-name': {'ce:given-name': 'Amvrossios C.',
#      'ce:initials': 'A.C.',
#      'ce:surname': 'Bagtzoglou',
#      'ce:indexed-name': 'Bagtzoglou A.'},
#     '@seq': '3',
#     'ce:initials': 'A.C.',
#     '@_fa': 'true',
#     'affiliation': {'@id': '60022659',
#      '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60022659'},
#     'ce:surname': 'Bagtzoglou',
#     '@auid': '7003300087',
#     'author-url': 'https://api.elsevier.com/content/author/author_id/7003300087',
#     '@force-array': 'true',
#     'ce:indexed-name': 'Bagtzoglou A.C.'},
#    {'ce:given-name': 'Dale D.',
#     'preferred-name': {'ce:given-name': 'Dale D.',
#      'ce:initials': 'D.D.',
#      'ce:surname': 'Werkema',
#      'ce:indexed-name': 'Werkema D.'},
#     '@seq': '4',
#     'ce:initials': 'D.D.',
#     '@_fa': 'true',
#     'affiliation': {'@id': '60021439',
#      '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60021439'},
#     'ce:surname': 'Werkema',
#     '@auid': '6603081105',
#     'author-url': 'https://api.elsevier.com/content/author/author_id/6603081105',
#     '@force-array': 'true',
#     'ce:indexed-name': 'Werkema D.D.'}]},
#  'url': 'https://api.elsevier.com/content/abstract/scopus_id/84978115007'}

# %%
reference_0['scopus-eid']
# Out:
# '2-s2.0-84978115007'

# %%
references = json['abstracts-retrieval-response']['references']['reference']

for reference in references:
    print(reference['scopus-eid'])
# Out:
# 2-s2.0-84978115007
# 2-s2.0-0036695720
# 2-s2.0-0036609180
# 2-s2.0-85007060782
# 2-s2.0-40449088905
# 2-s2.0-84906725860
# 2-s2.0-84924222057
# 2-s2.0-84871386956
# 2-s2.0-84868014007
# 2-s2.0-84855925873
# 2-s2.0-36749072655
# 2-s2.0-77951566656
# 2-s2.0-84907818061
# 2-s2.0-84976598255
# 2-s2.0-84910071426
# 2-s2.0-84893868781
# 2-s2.0-84976363286
# 2-s2.0-84962382655
# 2-s2.0-84878031896
# 2-s2.0-85027924941
# 2-s2.0-84906237126
# 2-s2.0-79955364443

# %% [markdown]
# With this information (the EIDs of a given article) is possible to build many diferents formats of output.
#
# The staff of the Elsevier API have built an python packge that wrapps many in a python friendly way of use the API. You can find the oficial github repository in [this link](https://github.com/scopus-api/scopus).
