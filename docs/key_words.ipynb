# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys

#https://stackoverflow.com/a/35273613
module_path = os.path.abspath(os.path.join('..'))

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pandas as pd
from scopuspep.scopuspep import Scopuspep

# %%
df = pd.read_csv('scopus_key_words.csv')

# %%
pd.options.display.max_colwidth = 100
df['Author Keywords']
# Out:
# 0      Geographical information systems; Land-Use suitability analysis; Multiple criteria decision anal...
# 1                          ANP; Boolean logic; DEMATEL; Fuzzy logic; Site selection; Waste management; WLC
# 2                    Decomposition Method; Geographic Information System; Landfill; Solid Waste Management
# 3                   GIS; Infrastructural planning; Landfill site; Multicriteria analysis; Weighted overlay
# 4                                                       AHP; Environment Management; GIS; Landfill; TOPSIS
# 5                       Dumpsite; GIS; Multi-criteria evaluation; Municipal solid waste; Sanitary landfill
# 6                                                          Bursa; GIS; Landfill; MCDM; Solid waste; TOPSIS
# 7      Analytical hierarchy process (AHP); Geographical information system (GIS); Index overlay; Indust...
# 8                                                      AHP; GIS; Kufa city; Landfill; MCDA; Site selection
# ...

# %%
df = df[df['Author Keywords'].notnull()]

article_key_words = df['Author Keywords'].tolist()
article_key_words
# Out:
# ['Geographical information systems; Land-Use suitability analysis; Multiple criteria decision analysis; Robustness analysis; UTASTAR method',
#  'ANP; Boolean logic; DEMATEL; Fuzzy logic; Site selection; Waste management; WLC',
#  'Decomposition Method; Geographic Information System; Landfill; Solid Waste Management',
#  'GIS; Infrastructural planning; Landfill site; Multicriteria analysis; Weighted overlay',
#  'AHP; Environment Management; GIS; Landfill; TOPSIS',
#  'Dumpsite; GIS; Multi-criteria evaluation; Municipal solid waste; Sanitary landfill',
#  'Bursa; GIS; Landfill; MCDM; Solid waste; TOPSIS',
#  'Analytical hierarchy process (AHP); Geographical information system (GIS); Index overlay; Industrial waste; Site selection',
#  'AHP; GIS; Kufa city; Landfill; MCDA; Site selection',
#  'Bahrain; GIS; Land reclamation; Landfill; Municipal solid waste',
#  'Coimbatore; GIS; landfill site; multi-criteria decision analysis; municipal solid waste; remote sensing',
# ...

# %%
# for key_words in article_key_words
words = [key_word for key_words in article_key_words for key_word in key_words.split('; ')]

words
# Out:
# ['Geographical information systems',
#  'Land-Use suitability analysis',
#  'Multiple criteria decision analysis',
#  'Robustness analysis',
#  'UTASTAR method',
#  'ANP',
#  'Boolean logic',
#  'DEMATEL',
#  'Fuzzy logic',
#  'Site selection',
#  'Waste management',
#  'WLC',
#  'Decomposition Method',
#  'Geographic Information System',
#  'Landfill',
#  'Solid Waste Management',
#  'GIS',
#  'Infrastructural planning',
#  'Landfill site',
#  'Multicriteria analysis',
#  'Weighted overlay',
#  'AHP',
#  'Environment Management',
#  'GIS',
#  'Landfill',
#  'TOPSIS',
#  'Dumpsite',
#  'GIS',
#  'Multi-criteria evaluation',
#  'Municipal solid waste',
#  'Sanitary landfill',
#  'Bursa',
#  'GIS',
#  'Landfill',
#  'MCDM',
#  'Solid waste',
#  'TOPSIS',
#  'Analytical hierarchy process (AHP)',
#  'Geographical information system (GIS)',
#  'Index overlay',
#  'Industrial waste',
#  'Site selection',
#  'AHP',
#  'GIS',
#  'Kufa city',
#  'Landfill',
#  'MCDA',
#  'Site selection',
# ...

# %%
s = pd.Series(words)
s = s.value_counts()
#s.to_csv('key_words.csv')
s
# Out:
# GIS                                                                                33
# Landfill                                                                           28
# Site selection                                                                     23
# Landfill site selection                                                            19
# Landfill siting                                                                    17
# Solid waste                                                                        15
# Municipal solid waste                                                              13
# Multi-criteria analysis                                                            10
# AHP                                                                                 9
# Waste management                                                                    8
# Analytical hierarchy process                                                        8
# ...
